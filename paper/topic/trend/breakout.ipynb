# %%
'''Charting'''
from systems.provided.rules.breakout import breakout
from systems.provided.rules.ewmac import ewmac_no_vol
from paper.topic.common_import import *

ins = 'BTC-USDT-SWAP'

_close = system.data.daily_prices(ins).tail(60)

_  = _close.plot(legend=True, figsize=(16, 4))
plt.title('{} {} - {}'.format(ins, _close.index[0], _close.index[-1]))
ax = breakout(_close, lookback=8).plot(legend=True, figsize=(16, 4), secondary_y=True)
_ = ax.hlines(0, _close.index[0], _close.index[-1], colors='r', linestyles='dashed')
plt.show()

_  = _close.plot(legend=True, figsize=(16, 4))
plt.title('{} {} - {}'.format(ins, _close.index[0], _close.index[-1]))
ax = ewmac_no_vol(_close, 4, 16).plot(legend=True, figsize=(16, 4), secondary_y=True)
_ = ax.hlines(0, _close.index[0], _close.index[-1], colors='r', linestyles='dashed')
plt.show()

_ = system.data.get_raw_price(ins).tail(24 * 30).plot(figsize=(16, 4))
# Out:
# /Users/weiranzhou/Code/pysystemtrade/sysobjects/futures_per_contract_prices.py:35: UserWarning: Pandas doesn't allow columns to be created via a new attribute name - see https://pandas.pydata.org/pandas-docs/stable/indexing.html#attribute-access
#   self._as_df = price_data_as_df
# /Users/weiranzhou/Code/pysystemtrade/sysobjects/futures_per_contract_prices.py:35: UserWarning: Pandas doesn't allow columns to be created via a new attribute name - see https://pandas.pydata.org/pandas-docs/stable/indexing.html#attribute-access
#   self._as_df = price_data_as_df
