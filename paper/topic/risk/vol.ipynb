# %%
# https://vlab.stern.nyu.edu/volatility/VOL.BTCUSD%3AFOREX-R.GARCH
from paper.topic.common_import import *

def t(ins = 'ETH-BUSD-Binance'):
    # system.data.hourly_prices(ins).tail(180).plot(figsize=Immerse_Size)
    # plt.show()
    # print(system.data.hourly_prices(ins).pct_change().describe())
    system.data.hourly_prices(ins).pct_change().rename(ins).plot(alpha=0.5, figsize=Immerse_Size, legend=True)
    # plt.show()


# t('BNB-USDT-Binance')
t('BTC-USDT-Binance')
t('ETH-USDT-Binance')
# t('DOGE-USDT-Binance')
# Out:
# /Users/weiranzhou/Code/pysystemtrade/sysobjects/futures_per_contract_prices.py:35: UserWarning: Pandas doesn't allow columns to be created via a new attribute name - see https://pandas.pydata.org/pandas-docs/stable/indexing.html#attribute-access
#   self._as_df = price_data_as_df
# /Users/weiranzhou/Code/pysystemtrade/sysobjects/futures_per_contract_prices.py:35: UserWarning: Pandas doesn't allow columns to be created via a new attribute name - see https://pandas.pydata.org/pandas-docs/stable/indexing.html#attribute-access
#   self._as_df = price_data_as_df
