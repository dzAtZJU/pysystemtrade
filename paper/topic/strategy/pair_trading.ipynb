# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from syscore.fileutils import get_filename_for_package
from paper.systems.crypto_system import perpetuals_system
from itables import show

def select(se, start, end):
    return se[(se.index >= start) &(se.index <= end)]


system = perpetuals_system(config='paper.systems.pair_trading.yaml')
# Out:
# Bad key text.latex.preview in file /opt/homebrew/Caskroom/miniconda/base/envs/trading/lib/python3.8/site-packages/matplotlib/mpl-data/stylelib/_classic_test.mplstyle, line 123 ('text.latex.preview : False')
# You probably need to get an updated matplotlibrc file from
# https://github.com/matplotlib/matplotlib/blob/v3.5.0/matplotlibrc.template
# or from the matplotlib source distribution
#
# Bad key mathtext.fallback_to_cm in file /opt/homebrew/Caskroom/miniconda/base/envs/trading/lib/python3.8/site-packages/matplotlib/mpl-data/stylelib/_classic_test.mplstyle, line 155 ('mathtext.fallback_to_cm : True  # When True, use symbols from the Computer Modern')
# You probably need to get an updated matplotlibrc file from
# https://github.com/matplotlib/matplotlib/blob/v3.5.0/matplotlibrc.template
# or from the matplotlib source distribution
#
# Bad key savefig.jpeg_quality in file /opt/homebrew/Caskroom/miniconda/base/envs/trading/lib/python3.8/site-packages/matplotlib/mpl-data/stylelib/_classic_test.mplstyle, line 418 ('savefig.jpeg_quality: 95       # when a jpeg is saved, the default quality parameter.')
# You probably need to get an updated matplotlibrc file from
# https://github.com/matplotlib/matplotlib/blob/v3.5.0/matplotlibrc.template
# or from the matplotlib source distribution
#
# Bad key savefig.frameon in file /opt/homebrew/Caskroom/miniconda/base/envs/trading/lib/python3.8/site-packages/matplotlib/mpl-data/stylelib/_classic_test.mplstyle, line 421 ('savefig.frameon : True')
# You probably need to get an updated matplotlibrc file from
# https://github.com/matplotlib/matplotlib/blob/v3.5.0/matplotlibrc.template
# or from the matplotlib source distribution
#
# Bad key verbose.level in file /opt/homebrew/Caskroom/miniconda/base/envs/trading/lib/python3.8/site-packages/matplotlib/mpl-data/stylelib/_classic_test.mplstyle, line 472 ('verbose.level  : silent      # one of silent, helpful, debug, debug-annoying')
# You probably need to get an updated matplotlibrc file from
# https://github.com/matplotlib/matplotlib/blob/v3.5.0/matplotlibrc.template
# or from the matplotlib source distribution
#
# Bad key verbose.fileo in file /opt/homebrew/Caskroom/miniconda/base/envs/trading/lib/python3.8/site-packages/matplotlib/mpl-data/stylelib/_classic_test.mplstyle, line 473 ('verbose.fileo  : sys.stdout  # a log filename, sys.stdout or sys.stderr')
# You probably need to get an updated matplotlibrc file from
# https://github.com/matplotlib/matplotlib/blob/v3.5.0/matplotlibrc.template
# or from the matplotlib source distribution
#
# Bad key keymap.all_axes in file /opt/homebrew/Caskroom/miniconda/base/envs/trading/lib/python3.8/site-packages/matplotlib/mpl-data/stylelib/_classic_test.mplstyle, line 490 ('keymap.all_axes : a                 # enable all axes')
# You probably need to get an updated matplotlibrc file from
# https://github.com/matplotlib/matplotlib/blob/v3.5.0/matplotlibrc.template
# or from the matplotlib source distribution
#
# Bad key animation.avconv_path in file /opt/homebrew/Caskroom/miniconda/base/envs/trading/lib/python3.8/site-packages/matplotlib/mpl-data/stylelib/_classic_test.mplstyle, line 501 ('animation.avconv_path: avconv     # Path to avconv binary. Without full path')
# You probably need to get an updated matplotlibrc file from
# https://github.com/matplotlib/matplotlib/blob/v3.5.0/matplotlibrc.template
# or from the matplotlib source distribution
#
# Bad key animation.avconv_args in file /opt/homebrew/Caskroom/miniconda/base/envs/trading/lib/python3.8/site-packages/matplotlib/mpl-data/stylelib/_classic_test.mplstyle, line 503 ('animation.avconv_args:            # Additional arguments to pass to avconv')
# You probably need to get an updated matplotlibrc file from
# https://github.com/matplotlib/matplotlib/blob/v3.5.0/matplotlibrc.template
# or from the matplotlib source distribution
# /opt/homebrew/Caskroom/miniconda/base/envs/trading/lib/python3.8/site-packages/arctic/store/_pandas_ndarray_store.py:8: FutureWarning: The Panel class is removed from pandas. Accessing it from the top-level namespace will also be removed in the next version
#   from pandas import Panel

# %%
from paper.systems.rules.pair_trading import cal_sd, si, pair_trading

st = '2000-01-01'
et = '2023-07-08'
p1 = 'UAL'
p2 = 'AAL'

select((system.data.daily_prices(p1).rename(p1)), st, et).plot(figsize=(15, 6), legend=True)
select((system.data.daily_prices(p2)).rename(p2), st, et).plot(secondary_y=True, legend=True)
plt.show()

# select((system.data.daily_prices(p1).rename(p1)).pct_change(), st, et).plot(figsize=(15, 6), legend=True)
# select((system.data.daily_prices(p2)).rename(p2).pct_change(), st, et).plot(secondary_y=True, legend=True)
# plt.show()

select(system.data.daily_prices(p1).rename(p1).pct_change() - system.data.daily_prices(p2).rename(p2).pct_change(), st, et).plot(figsize=(15, 6), legend=True)
plt.show()


select(si(system.data.daily_prices(p1), 10).rename(p1), st, et).plot(figsize=(15, 6), legend=True)
select(si(system.data.daily_prices(p2),10).rename(p2), st, et).plot(legend=True)
plt.show()

select(system.rules.get_raw_forecast(p1, "pair_trading"), st, et).plot(figsize=(15, 6), legend=True)
plt.show()
# select(system.rawdata.annualised_percentage_volatility("BNB-USDT-SWAP").tail(360).plot(secondary_y=True)

pl = select(system.accounts.pandl_for_instrument_forecast(p1, 'pair_trading'), st, et).rename(p1)
pl.cumsum().plot(figsize=(15, 6), legend=True)
pl2 = select(system.accounts.pandl_for_instrument_forecast(p2, 'pair_trading'), st, et).rename(p2)
pl2.cumsum().plot(figsize=(15, 6), legend=True)
plt.show()
(pl + pl2).cumsum().plot(figsize=(15, 6), legend=True)


# sd = cal_sd(system.data.daily_prices('BNB-USDT-SWAP'), system.data.daily_prices('ETH-USDT-SWAP'), 10).rename('BNB')
# sd = sd.clip(-0.4, 0.4)
# sd[(sd!=-0.4) & (sd!=0.4) & (sd!=0)] = np.nan
# sd = sd.ffill()
# sd.plot(figsize=(15, 6), legend=True)
# Out:
# /Users/weiranzhou/Code/pysystemtrade/sysobjects/futures_per_contract_prices.py:33: UserWarning: Pandas doesn't allow columns to be created via a new attribute name - see https://pandas.pydata.org/pandas-docs/stable/indexing.html#attribute-access
#   self._as_df = price_data_as_df
# /Users/weiranzhou/Code/pysystemtrade/sysobjects/futures_per_contract_prices.py:33: UserWarning: Pandas doesn't allow columns to be created via a new attribute name - see https://pandas.pydata.org/pandas-docs/stable/indexing.html#attribute-access
#   self._as_df = price_data_as_df
# /Users/weiranzhou/Code/pysystemtrade/sysobjects/futures_per_contract_prices.py:33: UserWarning: Pandas doesn't allow columns to be created via a new attribute name - see https://pandas.pydata.org/pandas-docs/stable/indexing.html#attribute-access
#   self._as_df = price_data_as_df
# /Users/weiranzhou/Code/pysystemtrade/sysobjects/futures_per_contract_prices.py:33: UserWarning: Pandas doesn't allow columns to be created via a new attribute name - see https://pandas.pydata.org/pandas-docs/stable/indexing.html#attribute-access
#   self._as_df = price_data_as_df
# /Users/weiranzhou/Code/pysystemtrade/sysobjects/futures_per_contract_prices.py:33: UserWarning: Pandas doesn't allow columns to be created via a new attribute name - see https://pandas.pydata.org/pandas-docs/stable/indexing.html#attribute-access
#   self._as_df = price_data_as_df
# <AxesSubplot:xlabel='index'>

# %%
pl = system.accounts.portfolio()
pl.cumsum().plot()
print(pl.sharpe())
print(pl.calmar())
print(pl.ann_mean())
# print(pl.avg_drawdown())
# print(pl.worst_drawdown())
# print(pl.time_in_drawdown())

# pct_pl = (pl / system.accounts.get_notional_capital()).rename('pct pl')
# pct_pl.plot(secondary_y=True, figsize=(15,4))
# cum_pl = pl.cumsum().rename('cum pl')
# cum_pl.plot()
# plt.show()

# btc = system.data.daily_prices('BTC-USDT-SWAP')
# btc.plot(figsize=(15,4))

# show(system.portfolio.get_instrument_weights())
# print((1500+2500)/1500)

# 1.4810551268906207
# 2.552101763758399
# 901.5131039472927
# -133.46537562934083
# -353.24339991037937
# 0.9274336283185841
# pl = system.accounts.pandl_for_instrument_forecast('ETH-USDT-SWAP', 'sd')
# pl.cumsum().plot()
# print(pl.sharpe())
# print(pl.calmar())
# print(pl.ann_mean())
# print(pl.avg_drawdown())
# print(pl.worst_drawdown())
# print(pl.time_in_drawdown())
# Out:
# -1.6753840658662071
# -0.3196612962657507
# -238.9889863070349

# %%
pl = system.accounts.portfolio()

pct_pl = (pl / system.accounts.get_notional_capital()).rename('pct pl')
pct_pl.plot(secondary_y=True, figsize=(15,4))
cum_pl = pl.cumsum().rename('cum pl')
cum_pl.plot()
plt.show()

btc = system.data.daily_prices('BTC-USDT-SWAP')
btc.plot(figsize=(15,4))

show(system.portfolio.get_instrument_weights())
print((1500+2500)/1500)

# %%
st = '2020-11-01'
et = '2021-01-01'

pl = system.accounts.portfolio().to_frame()
pl = select(pl, st, et)
pct_pl = (pl / system.accounts.get_notional_capital())
pct_pl.plot(secondary_y=True, figsize=(15,5))
cum_pl = pl.cumsum(axis=0)
cum_pl.plot(figsize=(15,5))
plt.show()

btc = system.data.daily_prices('BTC-USDT-SWAP')
btc = select(btc, st, et)
btc.plot(figsize=(15,5))
btc.pct_change().plot(secondary_y=True)
# Out:
# 2023-02-03 14:07:01 {'type': 'base_system'}  Following instruments are 'duplicate_markets' ['Another_thing', 'bad_thing']
# 2023-02-03 14:07:01 {'type': 'base_system'}  Following instruments are marked as 'ignore_instruments': not included: ['EXAMPLE']
# 2023-02-03 14:07:01 {'type': 'base_system'}  Following instruments removed entirely from sim: ['Another_thing', 'EXAMPLE', 'bad_thing']
# 2023-02-03 14:07:01 {'type': 'base_system', 'stage': 'accounts'}  Calculating pandl for portfolio
# 2023-02-03 14:07:01 {'type': 'base_system', 'stage': 'positionSize'}  Getting vol target
# 2023-02-03 14:07:01 {'type': 'base_system', 'stage': 'accounts', 'instrument_code': 'ADA-USDT-SWAP'}  Calculating pandl for instrument for ADA-USDT-SWAP
# 2023-02-03 14:07:01 {'type': 'base_system', 'stage': 'portfolio', 'instrument_code': 'ADA-USDT-SWAP'}  Calculating notional position for ADA-USDT-SWAP
# 2023-02-03 14:07:01 {'type': 'base_system', 'stage': 'portfolio'}  Calculating instrument weights
# 2023-02-03 14:07:01 {'type': 'base_system', 'stage': 'portfolio'}  Calculating raw instrument weights
# 2023-02-03 14:07:01 {'type': 'base_system'}  Following instruments are 'duplicate_markets' ['Another_thing', 'bad_thing']
# 2023-02-03 14:07:01 {'type': 'base_system'}  Following instruments are marked as 'ignore_instruments': not included: ['EXAMPLE']
# 2023-02-03 14:07:01 {'type': 'base_system'}  Following instruments are marked as 'bad_markets':  ['BAD_EXAMPLE']
# 2023-02-03 14:07:01 {'type': 'base_system'}  Following instruments have restricted trading:  ['RESTRICTED_EXAMPLE']
# 2023-02-03 14:07:01 {'type': 'base_system'}  Following instruments marked as not trading []
# 2023-02-03 14:07:01 {'type': 'base_system', 'stage': 'positionSize', 'instrument_code': 'ADA-USDT-SWAP'}  Calculating subsystem position for ADA-USDT-SWAP
# 2023-02-03 14:07:01 {'type': 'base_system', 'stage': 'positionSize', 'instrument_code': 'ADA-USDT-SWAP'}  Calculating volatility scalar for ADA-USDT-SWAP
# 2023-02-03 14:07:01 {'type': 'base_system', 'stage': 'positionSize', 'instrument_code': 'ADA-USDT-SWAP'}  Calculating instrument value vol for ADA-USDT-SWAP
# 2023-02-03 14:07:01 {'type': 'base_system', 'stage': 'positionSize', 'instrument_code': 'ADA-USDT-SWAP'}  Calculating instrument currency vol for ADA-USDT-SWAP
# 2023-02-03 14:07:01 {'type': 'base_system', 'stage': 'rawdata', 'instrument_code': 'ADA-USDT-SWAP'}  Retrieving natural prices for ADA-USDT-SWAP
# /Users/weiranzhou/Code/pysystemtrade/sysobjects/futures_per_contract_prices.py:33: UserWarning: Pandas doesn't allow columns to be created via a new attribute name - see https://pandas.pydata.org/pandas-docs/stable/indexing.html#attribute-access
#   self._as_df = price_data_as_df
# 2023-02-03 14:07:01 {'type': 'base_system', 'stage': 'rawdata', 'instrument_code': 'ADA-USDT-SWAP'}  Calculating daily prices for ADA-USDT-SWAP
# 2023-02-03 14:07:01 {'type': 'base_system', 'stage': 'rawdata', 'instrument_code': 'ADA-USDT-SWAP'}  Calculating daily volatility for ADA-USDT-SWAP
# 2023-02-03 14:07:01 {'type': 'base_system', 'stage': 'rawdata', 'instrument_code': 'ADA-USDT-SWAP'}  Calculating daily prices for ADA-USDT-SWAP
# 2023-02-03 14:07:02 {'type': 'base_system', 'stage': 'combForecast', 'instrument_code': 'ADA-USDT-SWAP'}  Calculating combined forecast for ADA-USDT-SWAP
# 2023-02-03 14:07:02 {'type': 'base_system', 'stage': 'forecastScaleCap', 'instrument_code': 'ADA-USDT-SWAP', 'rule_variation_name': 'ewmac4'}  Calculating capped forecast for ADA-USDT-SWAP ewmac4
# 2023-02-03 14:07:02 {'type': 'base_system', 'stage': 'rules', 'instrument_code': 'ADA-USDT-SWAP', 'rule_variation_name': 'ewmac4'}  Calculating raw forecast ADA-USDT-SWAP for ewmac4
# 2023-02-03 14:07:02 {'type': 'base_system', 'stage': 'rawdata', 'instrument_code': 'ADA-USDT-SWAP'}  Calculating daily prices for ADA-USDT-SWAP
# 2023-02-03 14:07:02 {'type': 'base_system', 'stage': 'forecastScaleCap', 'rule_variation_name': 'ewmac4'}  Getting cross sectional forecasts for scalar calculation for ewmac4 over ADA-USDT-SWAP, BNB-USDT, BTC-USDT-SWAP, DOGE-USDT-SWAP, ETH-USDT-SWAP, MATIC-USDT-SWAP, XRP-USDT-SWAP
# 2023-02-03 14:07:02 {'type': 'base_system', 'stage': 'rules', 'instrument_code': 'BNB-USDT', 'rule_variation_name': 'ewmac4'}  Calculating raw forecast BNB-USDT for ewmac4
# 2023-02-03 14:07:02 {'type': 'base_system', 'stage': 'rawdata', 'instrument_code': 'BNB-USDT'}  Calculating daily prices for BNB-USDT
# 2023-02-03 14:07:02 {'type': 'base_system', 'stage': 'rawdata', 'instrument_code': 'BNB-USDT'}  Calculating daily volatility for BNB-USDT
# 2023-02-03 14:07:02 {'type': 'base_system', 'stage': 'rawdata', 'instrument_code': 'BNB-USDT'}  Calculating daily prices for BNB-USDT
# 2023-02-03 14:07:03 {'type': 'base_system', 'stage': 'rules', 'instrument_code': 'BTC-USDT-SWAP', 'rule_variation_name': 'ewmac4'}  Calculating raw forecast BTC-USDT-SWAP for ewmac4
# 2023-02-03 14:07:03 {'type': 'base_system', 'stage': 'rawdata', 'instrument_code': 'BTC-USDT-SWAP'}  Calculating daily prices for BTC-USDT-SWAP
# 2023-02-03 14:07:03 {'type': 'base_system', 'stage': 'rawdata', 'instrument_code': 'BTC-USDT-SWAP'}  Calculating daily volatility for BTC-USDT-SWAP
# 2023-02-03 14:07:03 {'type': 'base_system', 'stage': 'rawdata', 'instrument_code': 'BTC-USDT-SWAP'}  Calculating daily prices for BTC-USDT-SWAP
# 2023-02-03 14:07:03 {'type': 'base_system', 'stage': 'rules', 'instrument_code': 'DOGE-USDT-SWAP', 'rule_variation_name': 'ewmac4'}  Calculating raw forecast DOGE-USDT-SWAP for ewmac4
# 2023-02-03 14:07:03 {'type': 'base_system', 'stage': 'rawdata', 'instrument_code': 'DOGE-USDT-SWAP'}  Calculating daily prices for DOGE-USDT-SWAP
# 2023-02-03 14:07:04 {'type': 'base_system', 'stage': 'rawdata', 'instrument_code': 'DOGE-USDT-SWAP'}  Calculating daily volatility for DOGE-USDT-SWAP
# 2023-02-03 14:07:04 {'type': 'base_system', 'stage': 'rawdata', 'instrument_code': 'DOGE-USDT-SWAP'}  Calculating daily prices for DOGE-USDT-SWAP
# 2023-02-03 14:07:04 {'type': 'base_system', 'stage': 'rules', 'instrument_code': 'ETH-USDT-SWAP', 'rule_variation_name': 'ewmac4'}  Calculating raw forecast ETH-USDT-SWAP for ewmac4
# 2023-02-03 14:07:04 {'type': 'base_system', 'stage': 'rawdata', 'instrument_code': 'ETH-USDT-SWAP'}  Calculating daily prices for ETH-USDT-SWAP
# 2023-02-03 14:07:04 {'type': 'base_system', 'stage': 'rawdata', 'instrument_code': 'ETH-USDT-SWAP'}  Calculating daily volatility for ETH-USDT-SWAP
# 2023-02-03 14:07:04 {'type': 'base_system', 'stage': 'rawdata', 'instrument_code': 'ETH-USDT-SWAP'}  Calculating daily prices for ETH-USDT-SWAP
# 2023-02-03 14:07:05 {'type': 'base_system', 'stage': 'rules', 'instrument_code': 'MATIC-USDT-SWAP', 'rule_variation_name': 'ewmac4'}  Calculating raw forecast MATIC-USDT-SWAP for ewmac4
# 2023-02-03 14:07:05 {'type': 'base_system', 'stage': 'rawdata', 'instrument_code': 'MATIC-USDT-SWAP'}  Calculating daily prices for MATIC-USDT-SWAP
# 2023-02-03 14:07:05 {'type': 'base_system', 'stage': 'rawdata', 'instrument_code': 'MATIC-USDT-SWAP'}  Calculating daily volatility for MATIC-USDT-SWAP
# 2023-02-03 14:07:05 {'type': 'base_system', 'stage': 'rawdata', 'instrument_code': 'MATIC-USDT-SWAP'}  Calculating daily prices for MATIC-USDT-SWAP
# 2023-02-03 14:07:05 {'type': 'base_system', 'stage': 'rules', 'instrument_code': 'XRP-USDT-SWAP', 'rule_variation_name': 'ewmac4'}  Calculating raw forecast XRP-USDT-SWAP for ewmac4
# 2023-02-03 14:07:05 {'type': 'base_system', 'stage': 'rawdata', 'instrument_code': 'XRP-USDT-SWAP'}  Calculating daily prices for XRP-USDT-SWAP
# 2023-02-03 14:07:05 {'type': 'base_system', 'stage': 'rawdata', 'instrument_code': 'XRP-USDT-SWAP'}  Calculating daily volatility for XRP-USDT-SWAP
# 2023-02-03 14:07:05 {'type': 'base_system', 'stage': 'rawdata', 'instrument_code': 'XRP-USDT-SWAP'}  Calculating daily prices for XRP-USDT-SWAP
# 2023-02-03 14:07:05 {'type': 'base_system', 'stage': 'forecastScaleCap', 'instrument_code': 'ADA-USDT-SWAP', 'rule_variation_name': 'ewmac6'}  Calculating capped forecast for ADA-USDT-SWAP ewmac6
# 2023-02-03 14:07:05 {'type': 'base_system', 'stage': 'rules', 'instrument_code': 'ADA-USDT-SWAP', 'rule_variation_name': 'ewmac6'}  Calculating raw forecast ADA-USDT-SWAP for ewmac6
# 2023-02-03 14:07:05 {'type': 'base_system', 'stage': 'rawdata', 'instrument_code': 'ADA-USDT-SWAP'}  Calculating daily prices for ADA-USDT-SWAP
# 2023-02-03 14:07:06 {'type': 'base_system', 'stage': 'forecastScaleCap', 'rule_variation_name': 'ewmac6'}  Getting cross sectional forecasts for scalar calculation for ewmac6 over ADA-USDT-SWAP, BNB-USDT, BTC-USDT-SWAP, DOGE-USDT-SWAP, ETH-USDT-SWAP, MATIC-USDT-SWAP, XRP-USDT-SWAP
# 2023-02-03 14:07:06 {'type': 'base_system', 'stage': 'rules', 'instrument_code': 'BNB-USDT', 'rule_variation_name': 'ewmac6'}  Calculating raw forecast BNB-USDT for ewmac6
# 2023-02-03 14:07:06 {'type': 'base_system', 'stage': 'rawdata', 'instrument_code': 'BNB-USDT'}  Calculating daily prices for BNB-USDT
# 2023-02-03 14:07:06 {'type': 'base_system', 'stage': 'rules', 'instrument_code': 'BTC-USDT-SWAP', 'rule_variation_name': 'ewmac6'}  Calculating raw forecast BTC-USDT-SWAP for ewmac6
# 2023-02-03 14:07:06 {'type': 'base_system', 'stage': 'rawdata', 'instrument_code': 'BTC-USDT-SWAP'}  Calculating daily prices for BTC-USDT-SWAP
# 2023-02-03 14:07:06 {'type': 'base_system', 'stage': 'rules', 'instrument_code': 'DOGE-USDT-SWAP', 'rule_variation_name': 'ewmac6'}  Calculating raw forecast DOGE-USDT-SWAP for ewmac6
# 2023-02-03 14:07:06 {'type': 'base_system', 'stage': 'rawdata', 'instrument_code': 'DOGE-USDT-SWAP'}  Calculating daily prices for DOGE-USDT-SWAP
# 2023-02-03 14:07:06 {'type': 'base_system', 'stage': 'rules', 'instrument_code': 'ETH-USDT-SWAP', 'rule_variation_name': 'ewmac6'}  Calculating raw forecast ETH-USDT-SWAP for ewmac6
# 2023-02-03 14:07:06 {'type': 'base_system', 'stage': 'rawdata', 'instrument_code': 'ETH-USDT-SWAP'}  Calculating daily prices for ETH-USDT-SWAP
# 2023-02-03 14:07:07 {'type': 'base_system', 'stage': 'rules', 'instrument_code': 'MATIC-USDT-SWAP', 'rule_variation_name': 'ewmac6'}  Calculating raw forecast MATIC-USDT-SWAP for ewmac6
# 2023-02-03 14:07:07 {'type': 'base_system', 'stage': 'rawdata', 'instrument_code': 'MATIC-USDT-SWAP'}  Calculating daily prices for MATIC-USDT-SWAP
# 2023-02-03 14:07:07 {'type': 'base_system', 'stage': 'rules', 'instrument_code': 'XRP-USDT-SWAP', 'rule_variation_name': 'ewmac6'}  Calculating raw forecast XRP-USDT-SWAP for ewmac6
# 2023-02-03 14:07:07 {'type': 'base_system', 'stage': 'rawdata', 'instrument_code': 'XRP-USDT-SWAP'}  Calculating daily prices for XRP-USDT-SWAP
# 2023-02-03 14:07:07 {'type': 'base_system', 'stage': 'combForecast', 'instrument_code': 'ADA-USDT-SWAP'}  Calculating forecast weights for ADA-USDT-SWAP
# 2023-02-03 14:07:07 {'type': 'base_system', 'stage': 'combForecast'}  Nested dict of forecast weights for ADA-USDT-SWAP {'ewmac4': 0.75, 'ewmac6': 0.25}: weights different by instrument
# 2023-02-03 14:07:07 {'type': 'base_system', 'stage': 'combForecast', 'instrument_code': 'ADA-USDT-SWAP'}  Only this set of rules ['ewmac4', 'ewmac6'] is cheap enough to trade for ADA-USDT-SWAP
# 2023-02-03 14:07:07 {'type': 'base_system', 'stage': 'combForecast', 'instrument_code': 'ADA-USDT-SWAP'}  Using fixed FDM multiplier of 1.000 for ADA-USDT-SWAP
# 2023-02-03 14:07:07 {'type': 'base_system', 'stage': 'combForecast', 'instrument_code': 'ADA-USDT-SWAP'}  No mapping applied for ADA-USDT-SWAP
# 2023-02-03 14:07:07 {'type': 'base_system', 'stage': 'positionSize', 'instrument_code': 'BNB-USDT'}  Calculating subsystem position for BNB-USDT
# 2023-02-03 14:07:07 {'type': 'base_system', 'stage': 'positionSize', 'instrument_code': 'BNB-USDT'}  Calculating volatility scalar for BNB-USDT
# 2023-02-03 14:07:07 {'type': 'base_system', 'stage': 'positionSize', 'instrument_code': 'BNB-USDT'}  Calculating instrument value vol for BNB-USDT
# 2023-02-03 14:07:07 {'type': 'base_system', 'stage': 'positionSize', 'instrument_code': 'BNB-USDT'}  Calculating instrument currency vol for BNB-USDT
# 2023-02-03 14:07:07 {'type': 'base_system', 'stage': 'rawdata', 'instrument_code': 'BNB-USDT'}  Retrieving natural prices for BNB-USDT
# 2023-02-03 14:07:07 {'type': 'base_system', 'stage': 'rawdata', 'instrument_code': 'BNB-USDT'}  Calculating daily prices for BNB-USDT
# 2023-02-03 14:07:07 {'type': 'base_system', 'stage': 'combForecast', 'instrument_code': 'BNB-USDT'}  Calculating combined forecast for BNB-USDT
# 2023-02-03 14:07:07 {'type': 'base_system', 'stage': 'forecastScaleCap', 'instrument_code': 'BNB-USDT', 'rule_variation_name': 'ewmac4'}  Calculating capped forecast for BNB-USDT ewmac4
# 2023-02-03 14:07:07 {'type': 'base_system', 'stage': 'forecastScaleCap', 'instrument_code': 'BNB-USDT', 'rule_variation_name': 'ewmac6'}  Calculating capped forecast for BNB-USDT ewmac6
# 2023-02-03 14:07:07 {'type': 'base_system', 'stage': 'combForecast', 'instrument_code': 'BNB-USDT'}  Calculating forecast weights for BNB-USDT
# 2023-02-03 14:07:07 {'type': 'base_system', 'stage': 'combForecast'}  Nested dict of forecast weights for BNB-USDT {'ewmac4': 0.75, 'ewmac6': 0.25}: weights different by instrument
# 2023-02-03 14:07:07 {'type': 'base_system', 'stage': 'combForecast', 'instrument_code': 'BNB-USDT'}  Only this set of rules ['ewmac4', 'ewmac6'] is cheap enough to trade for BNB-USDT
# 2023-02-03 14:07:07 {'type': 'base_system', 'stage': 'combForecast', 'instrument_code': 'BNB-USDT'}  Using fixed FDM multiplier of 1.000 for BNB-USDT
# 2023-02-03 14:07:07 {'type': 'base_system', 'stage': 'combForecast', 'instrument_code': 'BNB-USDT'}  No mapping applied for BNB-USDT
# 2023-02-03 14:07:07 {'type': 'base_system', 'stage': 'positionSize', 'instrument_code': 'BTC-USDT-SWAP'}  Calculating subsystem position for BTC-USDT-SWAP
# 2023-02-03 14:07:07 {'type': 'base_system', 'stage': 'positionSize', 'instrument_code': 'BTC-USDT-SWAP'}  Calculating volatility scalar for BTC-USDT-SWAP
# 2023-02-03 14:07:07 {'type': 'base_system', 'stage': 'positionSize', 'instrument_code': 'BTC-USDT-SWAP'}  Calculating instrument value vol for BTC-USDT-SWAP
# 2023-02-03 14:07:07 {'type': 'base_system', 'stage': 'positionSize', 'instrument_code': 'BTC-USDT-SWAP'}  Calculating instrument currency vol for BTC-USDT-SWAP
# 2023-02-03 14:07:07 {'type': 'base_system', 'stage': 'rawdata', 'instrument_code': 'BTC-USDT-SWAP'}  Retrieving natural prices for BTC-USDT-SWAP
# 2023-02-03 14:07:07 {'type': 'base_system', 'stage': 'rawdata', 'instrument_code': 'BTC-USDT-SWAP'}  Calculating daily prices for BTC-USDT-SWAP
# 2023-02-03 14:07:07 {'type': 'base_system', 'stage': 'combForecast', 'instrument_code': 'BTC-USDT-SWAP'}  Calculating combined forecast for BTC-USDT-SWAP
# 2023-02-03 14:07:07 {'type': 'base_system', 'stage': 'forecastScaleCap', 'instrument_code': 'BTC-USDT-SWAP', 'rule_variation_name': 'ewmac4'}  Calculating capped forecast for BTC-USDT-SWAP ewmac4
# 2023-02-03 14:07:07 {'type': 'base_system', 'stage': 'forecastScaleCap', 'instrument_code': 'BTC-USDT-SWAP', 'rule_variation_name': 'ewmac6'}  Calculating capped forecast for BTC-USDT-SWAP ewmac6
# 2023-02-03 14:07:07 {'type': 'base_system', 'stage': 'combForecast', 'instrument_code': 'BTC-USDT-SWAP'}  Calculating forecast weights for BTC-USDT-SWAP
# 2023-02-03 14:07:07 {'type': 'base_system', 'stage': 'combForecast'}  Nested dict of forecast weights for BTC-USDT-SWAP {'ewmac4': 0.75, 'ewmac6': 0.25}: weights different by instrument
# 2023-02-03 14:07:07 {'type': 'base_system', 'stage': 'combForecast', 'instrument_code': 'BTC-USDT-SWAP'}  Only this set of rules ['ewmac4', 'ewmac6'] is cheap enough to trade for BTC-USDT-SWAP
# 2023-02-03 14:07:08 {'type': 'base_system', 'stage': 'combForecast', 'instrument_code': 'BTC-USDT-SWAP'}  Using fixed FDM multiplier of 1.000 for BTC-USDT-SWAP
# 2023-02-03 14:07:08 {'type': 'base_system', 'stage': 'combForecast', 'instrument_code': 'BTC-USDT-SWAP'}  No mapping applied for BTC-USDT-SWAP
# 2023-02-03 14:07:08 {'type': 'base_system', 'stage': 'positionSize', 'instrument_code': 'DOGE-USDT-SWAP'}  Calculating subsystem position for DOGE-USDT-SWAP
# 2023-02-03 14:07:08 {'type': 'base_system', 'stage': 'positionSize', 'instrument_code': 'DOGE-USDT-SWAP'}  Calculating volatility scalar for DOGE-USDT-SWAP
# 2023-02-03 14:07:08 {'type': 'base_system', 'stage': 'positionSize', 'instrument_code': 'DOGE-USDT-SWAP'}  Calculating instrument value vol for DOGE-USDT-SWAP
# 2023-02-03 14:07:08 {'type': 'base_system', 'stage': 'positionSize', 'instrument_code': 'DOGE-USDT-SWAP'}  Calculating instrument currency vol for DOGE-USDT-SWAP
# 2023-02-03 14:07:08 {'type': 'base_system', 'stage': 'rawdata', 'instrument_code': 'DOGE-USDT-SWAP'}  Retrieving natural prices for DOGE-USDT-SWAP
# 2023-02-03 14:07:08 {'type': 'base_system', 'stage': 'rawdata', 'instrument_code': 'DOGE-USDT-SWAP'}  Calculating daily prices for DOGE-USDT-SWAP
# 2023-02-03 14:07:08 {'type': 'base_system', 'stage': 'combForecast', 'instrument_code': 'DOGE-USDT-SWAP'}  Calculating combined forecast for DOGE-USDT-SWAP
# 2023-02-03 14:07:08 {'type': 'base_system', 'stage': 'forecastScaleCap', 'instrument_code': 'DOGE-USDT-SWAP', 'rule_variation_name': 'ewmac4'}  Calculating capped forecast for DOGE-USDT-SWAP ewmac4
# 2023-02-03 14:07:08 {'type': 'base_system', 'stage': 'forecastScaleCap', 'instrument_code': 'DOGE-USDT-SWAP', 'rule_variation_name': 'ewmac6'}  Calculating capped forecast for DOGE-USDT-SWAP ewmac6
# 2023-02-03 14:07:08 {'type': 'base_system', 'stage': 'combForecast', 'instrument_code': 'DOGE-USDT-SWAP'}  Calculating forecast weights for DOGE-USDT-SWAP
# 2023-02-03 14:07:08 {'type': 'base_system', 'stage': 'combForecast'}  Nested dict of forecast weights for DOGE-USDT-SWAP {'ewmac4': 0.75, 'ewmac6': 0.25}: weights different by instrument
# 2023-02-03 14:07:08 {'type': 'base_system', 'stage': 'combForecast', 'instrument_code': 'DOGE-USDT-SWAP'}  Only this set of rules ['ewmac4', 'ewmac6'] is cheap enough to trade for DOGE-USDT-SWAP
# 2023-02-03 14:07:08 {'type': 'base_system', 'stage': 'combForecast', 'instrument_code': 'DOGE-USDT-SWAP'}  Using fixed FDM multiplier of 1.000 for DOGE-USDT-SWAP
# 2023-02-03 14:07:08 {'type': 'base_system', 'stage': 'combForecast', 'instrument_code': 'DOGE-USDT-SWAP'}  No mapping applied for DOGE-USDT-SWAP
# 2023-02-03 14:07:08 {'type': 'base_system', 'stage': 'positionSize', 'instrument_code': 'ETH-USDT-SWAP'}  Calculating subsystem position for ETH-USDT-SWAP
# 2023-02-03 14:07:08 {'type': 'base_system', 'stage': 'positionSize', 'instrument_code': 'ETH-USDT-SWAP'}  Calculating volatility scalar for ETH-USDT-SWAP
# 2023-02-03 14:07:08 {'type': 'base_system', 'stage': 'positionSize', 'instrument_code': 'ETH-USDT-SWAP'}  Calculating instrument value vol for ETH-USDT-SWAP
# 2023-02-03 14:07:08 {'type': 'base_system', 'stage': 'positionSize', 'instrument_code': 'ETH-USDT-SWAP'}  Calculating instrument currency vol for ETH-USDT-SWAP
# 2023-02-03 14:07:08 {'type': 'base_system', 'stage': 'rawdata', 'instrument_code': 'ETH-USDT-SWAP'}  Retrieving natural prices for ETH-USDT-SWAP
# 2023-02-03 14:07:08 {'type': 'base_system', 'stage': 'rawdata', 'instrument_code': 'ETH-USDT-SWAP'}  Calculating daily prices for ETH-USDT-SWAP
# 2023-02-03 14:07:08 {'type': 'base_system', 'stage': 'combForecast', 'instrument_code': 'ETH-USDT-SWAP'}  Calculating combined forecast for ETH-USDT-SWAP
# 2023-02-03 14:07:08 {'type': 'base_system', 'stage': 'forecastScaleCap', 'instrument_code': 'ETH-USDT-SWAP', 'rule_variation_name': 'ewmac4'}  Calculating capped forecast for ETH-USDT-SWAP ewmac4
# 2023-02-03 14:07:08 {'type': 'base_system', 'stage': 'forecastScaleCap', 'instrument_code': 'ETH-USDT-SWAP', 'rule_variation_name': 'ewmac6'}  Calculating capped forecast for ETH-USDT-SWAP ewmac6
# 2023-02-03 14:07:08 {'type': 'base_system', 'stage': 'combForecast', 'instrument_code': 'ETH-USDT-SWAP'}  Calculating forecast weights for ETH-USDT-SWAP
# 2023-02-03 14:07:08 {'type': 'base_system', 'stage': 'combForecast'}  Nested dict of forecast weights for ETH-USDT-SWAP {'ewmac4': 0.75, 'ewmac6': 0.25}: weights different by instrument
# 2023-02-03 14:07:08 {'type': 'base_system', 'stage': 'combForecast', 'instrument_code': 'ETH-USDT-SWAP'}  Only this set of rules ['ewmac4', 'ewmac6'] is cheap enough to trade for ETH-USDT-SWAP
# 2023-02-03 14:07:08 {'type': 'base_system', 'stage': 'combForecast', 'instrument_code': 'ETH-USDT-SWAP'}  Using fixed FDM multiplier of 1.000 for ETH-USDT-SWAP
# 2023-02-03 14:07:08 {'type': 'base_system', 'stage': 'combForecast', 'instrument_code': 'ETH-USDT-SWAP'}  No mapping applied for ETH-USDT-SWAP
# 2023-02-03 14:07:08 {'type': 'base_system', 'stage': 'positionSize', 'instrument_code': 'MATIC-USDT-SWAP'}  Calculating subsystem position for MATIC-USDT-SWAP
# 2023-02-03 14:07:08 {'type': 'base_system', 'stage': 'positionSize', 'instrument_code': 'MATIC-USDT-SWAP'}  Calculating volatility scalar for MATIC-USDT-SWAP
# 2023-02-03 14:07:08 {'type': 'base_system', 'stage': 'positionSize', 'instrument_code': 'MATIC-USDT-SWAP'}  Calculating instrument value vol for MATIC-USDT-SWAP
# 2023-02-03 14:07:08 {'type': 'base_system', 'stage': 'positionSize', 'instrument_code': 'MATIC-USDT-SWAP'}  Calculating instrument currency vol for MATIC-USDT-SWAP
# 2023-02-03 14:07:08 {'type': 'base_system', 'stage': 'rawdata', 'instrument_code': 'MATIC-USDT-SWAP'}  Retrieving natural prices for MATIC-USDT-SWAP
# 2023-02-03 14:07:08 {'type': 'base_system', 'stage': 'rawdata', 'instrument_code': 'MATIC-USDT-SWAP'}  Calculating daily prices for MATIC-USDT-SWAP
# 2023-02-03 14:07:08 {'type': 'base_system', 'stage': 'combForecast', 'instrument_code': 'MATIC-USDT-SWAP'}  Calculating combined forecast for MATIC-USDT-SWAP
# 2023-02-03 14:07:08 {'type': 'base_system', 'stage': 'forecastScaleCap', 'instrument_code': 'MATIC-USDT-SWAP', 'rule_variation_name': 'ewmac4'}  Calculating capped forecast for MATIC-USDT-SWAP ewmac4
# 2023-02-03 14:07:08 {'type': 'base_system', 'stage': 'forecastScaleCap', 'instrument_code': 'MATIC-USDT-SWAP', 'rule_variation_name': 'ewmac6'}  Calculating capped forecast for MATIC-USDT-SWAP ewmac6
# 2023-02-03 14:07:08 {'type': 'base_system', 'stage': 'combForecast', 'instrument_code': 'MATIC-USDT-SWAP'}  Calculating forecast weights for MATIC-USDT-SWAP
# 2023-02-03 14:07:08 {'type': 'base_system', 'stage': 'combForecast'}  Nested dict of forecast weights for MATIC-USDT-SWAP {'ewmac4': 0.75, 'ewmac6': 0.25}: weights different by instrument
# 2023-02-03 14:07:08 {'type': 'base_system', 'stage': 'combForecast', 'instrument_code': 'MATIC-USDT-SWAP'}  Only this set of rules ['ewmac4', 'ewmac6'] is cheap enough to trade for MATIC-USDT-SWAP
# 2023-02-03 14:07:08 {'type': 'base_system', 'stage': 'combForecast', 'instrument_code': 'MATIC-USDT-SWAP'}  Using fixed FDM multiplier of 1.000 for MATIC-USDT-SWAP
# 2023-02-03 14:07:08 {'type': 'base_system', 'stage': 'combForecast', 'instrument_code': 'MATIC-USDT-SWAP'}  No mapping applied for MATIC-USDT-SWAP
# 2023-02-03 14:07:08 {'type': 'base_system', 'stage': 'positionSize', 'instrument_code': 'XRP-USDT-SWAP'}  Calculating subsystem position for XRP-USDT-SWAP
# 2023-02-03 14:07:08 {'type': 'base_system', 'stage': 'positionSize', 'instrument_code': 'XRP-USDT-SWAP'}  Calculating volatility scalar for XRP-USDT-SWAP
# 2023-02-03 14:07:08 {'type': 'base_system', 'stage': 'positionSize', 'instrument_code': 'XRP-USDT-SWAP'}  Calculating instrument value vol for XRP-USDT-SWAP
# 2023-02-03 14:07:08 {'type': 'base_system', 'stage': 'positionSize', 'instrument_code': 'XRP-USDT-SWAP'}  Calculating instrument currency vol for XRP-USDT-SWAP
# 2023-02-03 14:07:08 {'type': 'base_system', 'stage': 'rawdata', 'instrument_code': 'XRP-USDT-SWAP'}  Retrieving natural prices for XRP-USDT-SWAP
# 2023-02-03 14:07:08 {'type': 'base_system', 'stage': 'rawdata', 'instrument_code': 'XRP-USDT-SWAP'}  Calculating daily prices for XRP-USDT-SWAP
# 2023-02-03 14:07:08 {'type': 'base_system', 'stage': 'combForecast', 'instrument_code': 'XRP-USDT-SWAP'}  Calculating combined forecast for XRP-USDT-SWAP
# 2023-02-03 14:07:08 {'type': 'base_system', 'stage': 'forecastScaleCap', 'instrument_code': 'XRP-USDT-SWAP', 'rule_variation_name': 'ewmac4'}  Calculating capped forecast for XRP-USDT-SWAP ewmac4
# 2023-02-03 14:07:08 {'type': 'base_system', 'stage': 'forecastScaleCap', 'instrument_code': 'XRP-USDT-SWAP', 'rule_variation_name': 'ewmac6'}  Calculating capped forecast for XRP-USDT-SWAP ewmac6
# 2023-02-03 14:07:08 {'type': 'base_system', 'stage': 'combForecast', 'instrument_code': 'XRP-USDT-SWAP'}  Calculating forecast weights for XRP-USDT-SWAP
# 2023-02-03 14:07:08 {'type': 'base_system', 'stage': 'combForecast'}  Nested dict of forecast weights for XRP-USDT-SWAP {'ewmac4': 0.75, 'ewmac6': 0.25}: weights different by instrument
# 2023-02-03 14:07:08 {'type': 'base_system', 'stage': 'combForecast', 'instrument_code': 'XRP-USDT-SWAP'}  Only this set of rules ['ewmac4', 'ewmac6'] is cheap enough to trade for XRP-USDT-SWAP
# 2023-02-03 14:07:08 {'type': 'base_system', 'stage': 'combForecast', 'instrument_code': 'XRP-USDT-SWAP'}  Using fixed FDM multiplier of 1.000 for XRP-USDT-SWAP
# 2023-02-03 14:07:08 {'type': 'base_system', 'stage': 'combForecast', 'instrument_code': 'XRP-USDT-SWAP'}  No mapping applied for XRP-USDT-SWAP
# 2023-02-03 14:07:08 {'type': 'base_system', 'stage': 'portfolio'}  Using fixed diversification multiplier 1.000000
# 2023-02-03 14:07:08 {'type': 'base_system', 'stage': 'portfolio'}  No risk overlay in config: won't apply risk scaling
# 2023-02-03 14:07:08 {'type': 'base_system', 'stage': 'portfolio', 'instrument_code': 'ADA-USDT-SWAP'}  Calculating buffers for ADA-USDT-SWAP
# 2023-02-03 14:07:08 {'type': 'base_system', 'stage': 'portfolio', 'instrument_code': 'ADA-USDT-SWAP'}  Calculating forecast method buffers for ADA-USDT-SWAP
# 2023-02-03 14:07:08 {'type': 'base_system', 'stage': 'accounts'}  Calculating buffered positions
# 2023-02-03 14:07:08 {'type': 'base_system', 'stage': 'accounts', 'instrument_code': 'ADA-USDT-SWAP'}  Calculating pandl for instrument for ADA-USDT-SWAP
# /Users/weiranzhou/Code/pysystemtrade/sysobjects/futures_per_contract_prices.py:33: UserWarning: Pandas doesn't allow columns to be created via a new attribute name - see https://pandas.pydata.org/pandas-docs/stable/indexing.html#attribute-access
#   self._as_df = price_data_as_df
# 2023-02-03 14:07:09 {'type': 'base_system', 'stage': 'accounts', 'instrument_code': 'BNB-USDT'}  Calculating pandl for instrument for BNB-USDT
# 2023-02-03 14:07:09 {'type': 'base_system', 'stage': 'portfolio', 'instrument_code': 'BNB-USDT'}  Calculating notional position for BNB-USDT
# 2023-02-03 14:07:09 {'type': 'base_system', 'stage': 'portfolio', 'instrument_code': 'BNB-USDT'}  Calculating buffers for BNB-USDT
# 2023-02-03 14:07:09 {'type': 'base_system', 'stage': 'portfolio', 'instrument_code': 'BNB-USDT'}  Calculating forecast method buffers for BNB-USDT
# 2023-02-03 14:07:09 {'type': 'base_system', 'stage': 'accounts'}  Calculating buffered positions
# 2023-02-03 14:07:09 {'type': 'base_system', 'stage': 'accounts', 'instrument_code': 'BNB-USDT'}  Calculating pandl for instrument for BNB-USDT
# 2023-02-03 14:07:09 {'type': 'base_system', 'stage': 'accounts', 'instrument_code': 'BTC-USDT-SWAP'}  Calculating pandl for instrument for BTC-USDT-SWAP
# 2023-02-03 14:07:09 {'type': 'base_system', 'stage': 'portfolio', 'instrument_code': 'BTC-USDT-SWAP'}  Calculating notional position for BTC-USDT-SWAP
# 2023-02-03 14:07:09 {'type': 'base_system', 'stage': 'portfolio', 'instrument_code': 'BTC-USDT-SWAP'}  Calculating buffers for BTC-USDT-SWAP
# 2023-02-03 14:07:09 {'type': 'base_system', 'stage': 'portfolio', 'instrument_code': 'BTC-USDT-SWAP'}  Calculating forecast method buffers for BTC-USDT-SWAP
# 2023-02-03 14:07:09 {'type': 'base_system', 'stage': 'accounts'}  Calculating buffered positions
# 2023-02-03 14:07:09 {'type': 'base_system', 'stage': 'accounts', 'instrument_code': 'BTC-USDT-SWAP'}  Calculating pandl for instrument for BTC-USDT-SWAP
# 2023-02-03 14:07:09 {'type': 'base_system', 'stage': 'accounts', 'instrument_code': 'DOGE-USDT-SWAP'}  Calculating pandl for instrument for DOGE-USDT-SWAP
# 2023-02-03 14:07:09 {'type': 'base_system', 'stage': 'portfolio', 'instrument_code': 'DOGE-USDT-SWAP'}  Calculating notional position for DOGE-USDT-SWAP
# 2023-02-03 14:07:09 {'type': 'base_system', 'stage': 'portfolio', 'instrument_code': 'DOGE-USDT-SWAP'}  Calculating buffers for DOGE-USDT-SWAP
# 2023-02-03 14:07:09 {'type': 'base_system', 'stage': 'portfolio', 'instrument_code': 'DOGE-USDT-SWAP'}  Calculating forecast method buffers for DOGE-USDT-SWAP
# 2023-02-03 14:07:09 {'type': 'base_system', 'stage': 'accounts'}  Calculating buffered positions
# 2023-02-03 14:07:09 {'type': 'base_system', 'stage': 'accounts', 'instrument_code': 'DOGE-USDT-SWAP'}  Calculating pandl for instrument for DOGE-USDT-SWAP
# 2023-02-03 14:07:09 {'type': 'base_system', 'stage': 'accounts', 'instrument_code': 'ETH-USDT-SWAP'}  Calculating pandl for instrument for ETH-USDT-SWAP
# 2023-02-03 14:07:09 {'type': 'base_system', 'stage': 'portfolio', 'instrument_code': 'ETH-USDT-SWAP'}  Calculating notional position for ETH-USDT-SWAP
# 2023-02-03 14:07:09 {'type': 'base_system', 'stage': 'portfolio', 'instrument_code': 'ETH-USDT-SWAP'}  Calculating buffers for ETH-USDT-SWAP
# 2023-02-03 14:07:09 {'type': 'base_system', 'stage': 'portfolio', 'instrument_code': 'ETH-USDT-SWAP'}  Calculating forecast method buffers for ETH-USDT-SWAP
# 2023-02-03 14:07:09 {'type': 'base_system', 'stage': 'accounts'}  Calculating buffered positions
# 2023-02-03 14:07:09 {'type': 'base_system', 'stage': 'accounts', 'instrument_code': 'ETH-USDT-SWAP'}  Calculating pandl for instrument for ETH-USDT-SWAP
# 2023-02-03 14:07:10 {'type': 'base_system', 'stage': 'accounts', 'instrument_code': 'MATIC-USDT-SWAP'}  Calculating pandl for instrument for MATIC-USDT-SWAP
# 2023-02-03 14:07:10 {'type': 'base_system', 'stage': 'portfolio', 'instrument_code': 'MATIC-USDT-SWAP'}  Calculating notional position for MATIC-USDT-SWAP
# 2023-02-03 14:07:10 {'type': 'base_system', 'stage': 'portfolio', 'instrument_code': 'MATIC-USDT-SWAP'}  Calculating buffers for MATIC-USDT-SWAP
# 2023-02-03 14:07:10 {'type': 'base_system', 'stage': 'portfolio', 'instrument_code': 'MATIC-USDT-SWAP'}  Calculating forecast method buffers for MATIC-USDT-SWAP
# 2023-02-03 14:07:10 {'type': 'base_system', 'stage': 'accounts'}  Calculating buffered positions
# 2023-02-03 14:07:10 {'type': 'base_system', 'stage': 'accounts', 'instrument_code': 'MATIC-USDT-SWAP'}  Calculating pandl for instrument for MATIC-USDT-SWAP
# 2023-02-03 14:07:10 {'type': 'base_system', 'stage': 'accounts', 'instrument_code': 'XRP-USDT-SWAP'}  Calculating pandl for instrument for XRP-USDT-SWAP
# 2023-02-03 14:07:10 {'type': 'base_system', 'stage': 'portfolio', 'instrument_code': 'XRP-USDT-SWAP'}  Calculating notional position for XRP-USDT-SWAP
# 2023-02-03 14:07:10 {'type': 'base_system', 'stage': 'portfolio', 'instrument_code': 'XRP-USDT-SWAP'}  Calculating buffers for XRP-USDT-SWAP
# 2023-02-03 14:07:10 {'type': 'base_system', 'stage': 'portfolio', 'instrument_code': 'XRP-USDT-SWAP'}  Calculating forecast method buffers for XRP-USDT-SWAP
# 2023-02-03 14:07:10 {'type': 'base_system', 'stage': 'accounts'}  Calculating buffered positions
# 2023-02-03 14:07:10 {'type': 'base_system', 'stage': 'accounts', 'instrument_code': 'XRP-USDT-SWAP'}  Calculating pandl for instrument for XRP-USDT-SWAP
# /Users/weiranzhou/Code/pysystemtrade/sysobjects/futures_per_contract_prices.py:33: UserWarning: Pandas doesn't allow columns to be created via a new attribute name - see https://pandas.pydata.org/pandas-docs/stable/indexing.html#attribute-access
#   self._as_df = price_data_as_df
# <AxesSubplot:>

# %%
import pandas as pd
st = '2022-12-25'
et = '2023-03-01'

position_list = []
for ins in system.portfolio.get_instrument_list():
    if 'DOGE' in ins:
        continue
    position = system.portfolio.get_actual_position(ins).rename(ins)
    position = select(position, st, et)
    position_list.append(position)
pd.concat(position_list, axis=1).plot(secondary_y=True, figsize=(15,4), legend=True)
plt.show()

# btc = system.data.daily_prices('BTC-USDT-SWAP')
# btc = select(btc, st, et)
# btc.plot(figsize=(15,4))
# btc.pct_change().rename('pct change').plot(secondary_y=True, legend=True)

# print(19_000 * 5 * 0.01  / system.accounts.get_notional_capital() )

# %%
import pandas as pd
from syscore.dateutils import ROOT_BDAYS_INYEAR


st = '2020-11-16'
et = '2020-12-01'

tmp_list = []
for ins in system.portfolio.get_instrument_list():
    tmp = system.positionSize.get_price_volatility (ins).rename(ins)
    tmp = select(tmp, st, et)
    tmp_list.append(tmp)
pd.concat(tmp_list, axis=1).plot(secondary_y=True, figsize=(15,4), legend=True)
plt.show()

btc = system.data.daily_prices('BTC-USDT-SWAP')
btc = select(btc, st, et)
btc.plot(figsize=(15,4))
btc.pct_change().plot(secondary_y=True)

print(ROOT_BDAYS_INYEAR * 3)
# Out:
# /Users/weiranzhou/Code/pysystemtrade/sysobjects/futures_per_contract_prices.py:33: UserWarning: Pandas doesn't allow columns to be created via a new attribute name - see https://pandas.pydata.org/pandas-docs/stable/indexing.html#attribute-access
#   self._as_df = price_data_as_df
# 57.0

# %%
import ccxt
from paper.sysinit.scrape_okx_history_prices import fetch_once

st = '2020-11-21T00:00+00' 
et = '2020-12-01' 
exchange = ccxt.binance()
exchange = ccxt.binanceusdm()
exchange = ccxt.okex5()
symbol = 'BTC/USDT'
symbol = 'BTC-USDT-SWAP'
df = fetch_once(st, symbol, '1d', exhcnage=exchange)
prices = df[df.index<=et]
prices = prices.loc[:, 4]
prices.plot(figsize=(15,5))
prices.pct_change().rename('pct change').plot(figsize=(15,5), secondary_y=True, legend=True)
# Out:
# <AxesSubplot:>

# %%
import ccxt
from paper.sysinit.scrape_okx_history_prices import fetch_once

st = '2020-11-25T10:00+08' 
et = '2020-11-27' 
exchange = ccxt.binance()
exchange = ccxt.binanceusdm()
exchange = ccxt.okex5()
symbol = 'BTC/USDT'
symbol = 'BTC-USDT-SWAP'
df = fetch_once(st, symbol, '1h', exhcnage=exchange)
prices = df[df.index<=et]
prices = prices.loc[:, 4]
prices.plot(figsize=(15,5))
prices.pct_change().plot(figsize=(15,5), secondary_y=True)
# Out:
# <AxesSubplot:>

# %%
show(system.positionSize.get_subsystem_position('BTC-USDT-SWAP').tail(30))
system.accounts.pandl_for_subsystem('BTC-USDT-SWAP').tail(30).cumsum().plot()
print(250 / 1500)
print(30 / (361 ** 0.5))
# Out:
# <style>.itables table td {
#     text-overflow: ellipsis;
#     overflow: hidden;
# }
#
# .itables table th {
#     text-overflow: ellipsis;
#     overflow: hidden;
# }
#
# .itables thead input {
#     width: 100%;
#     padding: 3px;
#     box-sizing: border-box;
# }
#
# .itables tfoot input {
#     width: 100%;
#     padding: 3px;
#     box-sizing: border-box;
# }
# </style>
# <div class="itables">
# <table id="c81e9d5d-ba19-4d7f-9939-e414a4da939b" class="display nowrap"style="table-layout:auto;width:auto;margin:auto;caption-side:bottom"><thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>0</th>
#     </tr>
#     <tr>
#       <th>index</th>
#       <th></th>
#     </tr>
#   </thead><tbody><tr><td>Loading... (need <a href=https://mwouts.github.io/itables/troubleshooting.html>help</a>?)</td></tr></tbody></table>
# <link rel="stylesheet" type="text/css" href="https://cdn.datatables.net/1.13.1/css/jquery.dataTables.min.css">
# <script type="module">
#     // Import jquery and DataTable
#     import 'https://code.jquery.com/jquery-3.6.0.min.js';
#     import dt from 'https://cdn.datatables.net/1.12.1/js/jquery.dataTables.mjs';
#     dt($);
#
#     // Define the table data
#     const data = [["2023-01-05", -0.059078], ["2023-01-06", 0.030721], ["2023-01-07", 0.40028], ["2023-01-08", 0.639287], ["2023-01-09", 1.373362], ["2023-01-10", 1.896885], ["2023-01-11", 2.641812], ["2023-01-12", 4.354309], ["2023-01-13", 6.308351], ["2023-01-14", 6.666039], ["2023-01-15", 6.312595], ["2023-01-16", 6.594995], ["2023-01-17", 6.853127], ["2023-01-18", 6.90501], ["2023-01-19", 6.738779], ["2023-01-20", 6.955445], ["2023-01-21", 6.693773], ["2023-01-22", 6.314582], ["2023-01-23", 6.373656], ["2023-01-24", 6.550113], ["2023-01-25", 6.406034], ["2023-01-26", 6.702482], ["2023-01-27", 6.586861], ["2023-01-28", 6.285916], ["2023-01-29", 6.204864], ["2023-01-30", 6.350247], ["2023-01-31", 5.1337], ["2023-02-01", 4.634638], ["2023-02-02", 5.2029], ["2023-02-03", 5.018549]];
#
#     // Define the dt_args
#     let dt_args = {"order": []};
#     dt_args["data"] = data;
#
#     $(document).ready(function () {
#
#         $('#c81e9d5d-ba19-4d7f-9939-e414a4da939b').DataTable(dt_args);
#     });
# </script>
# </div>
# 2023-02-03 11:49:53 {'type': 'base_system', 'stage': 'accounts', 'instrument_code': 'BTC-USDT-SWAP'}  Calculating pandl for subsystem for instrument BTC-USDT-SWAP
# /Users/weiranzhou/Code/pysystemtrade/sysobjects/futures_per_contract_prices.py:33: UserWarning: Pandas doesn't allow columns to be created via a new attribute name - see https://pandas.pydata.org/pandas-docs/stable/indexing.html#attribute-access
#   self._as_df = price_data_as_df
# 2023-02-03 11:49:53 {'type': 'base_system', 'stage': 'positionSize', 'instrument_code': 'BTC-USDT-SWAP'}  Calculating buffers for BTC-USDT-SWAP
# 2023-02-03 11:49:53 {'type': 'base_system', 'stage': 'positionSize', 'instrument_code': 'BTC-USDT-SWAP'}  Calculating forecast method buffers for BTC-USDT-SWAP
# 2023-02-03 11:49:53 {'type': 'base_system', 'stage': 'accounts'}  Calculating buffered subsystem positions
# 0.16666666666666666
# 1.5789473684210527

# %%
system.accounts.pandl_for_subsystem('BTC-USDT-SWAP').stats()
system.accounts.pandl_for_subsystem('BTC-USDT-SWAP').cumsum().plot()
# Out:
# 2023-02-02 17:52:12 {'type': 'base_system', 'stage': 'accounts', 'instrument_code': 'BTC-USDT-SWAP'}  Calculating pandl for subsystem for instrument BTC-USDT-SWAP
# 2023-02-02 17:52:12 {'type': 'base_system'}  Following instruments are 'duplicate_markets' ['Another_thing', 'bad_thing']
# 2023-02-02 17:52:12 {'type': 'base_system'}  Following instruments are marked as 'ignore_instruments': not included: ['EXAMPLE']
# 2023-02-02 17:52:12 {'type': 'base_system'}  Following instruments removed entirely from sim: ['Another_thing', 'EXAMPLE', 'bad_thing']
# /Users/weiranzhou/Code/pysystemtrade/sysobjects/futures_per_contract_prices.py:33: UserWarning: Pandas doesn't allow columns to be created via a new attribute name - see https://pandas.pydata.org/pandas-docs/stable/indexing.html#attribute-access
#   self._as_df = price_data_as_df
# 2023-02-02 17:52:12 {'type': 'base_system', 'stage': 'positionSize', 'instrument_code': 'BTC-USDT-SWAP'}  Calculating subsystem position for BTC-USDT-SWAP
# 2023-02-02 17:52:12 {'type': 'base_system', 'stage': 'positionSize', 'instrument_code': 'BTC-USDT-SWAP'}  Calculating volatility scalar for BTC-USDT-SWAP
# 2023-02-02 17:52:12 {'type': 'base_system', 'stage': 'positionSize', 'instrument_code': 'BTC-USDT-SWAP'}  Calculating instrument value vol for BTC-USDT-SWAP
# 2023-02-02 17:52:12 {'type': 'base_system', 'stage': 'positionSize', 'instrument_code': 'BTC-USDT-SWAP'}  Calculating instrument currency vol for BTC-USDT-SWAP
# 2023-02-02 17:52:12 {'type': 'base_system', 'stage': 'rawdata', 'instrument_code': 'BTC-USDT-SWAP'}  Retrieving natural prices for BTC-USDT-SWAP
# 2023-02-02 17:52:12 {'type': 'base_system', 'stage': 'rawdata', 'instrument_code': 'BTC-USDT-SWAP'}  Calculating daily prices for BTC-USDT-SWAP
# 2023-02-02 17:52:13 {'type': 'base_system', 'stage': 'rawdata', 'instrument_code': 'BTC-USDT-SWAP'}  Calculating daily volatility for BTC-USDT-SWAP
# 2023-02-02 17:52:13 {'type': 'base_system', 'stage': 'rawdata', 'instrument_code': 'BTC-USDT-SWAP'}  Calculating daily prices for BTC-USDT-SWAP
# 2023-02-02 17:52:13 {'type': 'base_system', 'stage': 'combForecast', 'instrument_code': 'BTC-USDT-SWAP'}  Calculating combined forecast for BTC-USDT-SWAP
# 2023-02-02 17:52:13 {'type': 'base_system', 'stage': 'forecastScaleCap', 'instrument_code': 'BTC-USDT-SWAP', 'rule_variation_name': 'ewmac4'}  Calculating capped forecast for BTC-USDT-SWAP ewmac4
# 2023-02-02 17:52:13 {'type': 'base_system', 'stage': 'rules', 'instrument_code': 'BTC-USDT-SWAP', 'rule_variation_name': 'ewmac4'}  Calculating raw forecast BTC-USDT-SWAP for ewmac4
# 2023-02-02 17:52:13 {'type': 'base_system', 'stage': 'rawdata', 'instrument_code': 'BTC-USDT-SWAP'}  Calculating daily prices for BTC-USDT-SWAP
# 2023-02-02 17:52:13 {'type': 'base_system', 'stage': 'forecastScaleCap', 'rule_variation_name': 'ewmac4'}  Getting cross sectional forecasts for scalar calculation for ewmac4 over BTC-USDT-SWAP
# 2023-02-02 17:52:13 {'type': 'base_system', 'stage': 'forecastScaleCap', 'instrument_code': 'BTC-USDT-SWAP', 'rule_variation_name': 'ewmac6'}  Calculating capped forecast for BTC-USDT-SWAP ewmac6
# 2023-02-02 17:52:13 {'type': 'base_system', 'stage': 'rules', 'instrument_code': 'BTC-USDT-SWAP', 'rule_variation_name': 'ewmac6'}  Calculating raw forecast BTC-USDT-SWAP for ewmac6
# 2023-02-02 17:52:13 {'type': 'base_system', 'stage': 'rawdata', 'instrument_code': 'BTC-USDT-SWAP'}  Calculating daily prices for BTC-USDT-SWAP
# 2023-02-02 17:52:13 {'type': 'base_system', 'stage': 'forecastScaleCap', 'rule_variation_name': 'ewmac6'}  Getting cross sectional forecasts for scalar calculation for ewmac6 over BTC-USDT-SWAP
# 2023-02-02 17:52:13 {'type': 'base_system', 'stage': 'combForecast', 'instrument_code': 'BTC-USDT-SWAP'}  Calculating forecast weights for BTC-USDT-SWAP
# 2023-02-02 17:52:13 {'type': 'base_system', 'stage': 'combForecast'}  Nested dict of forecast weights for BTC-USDT-SWAP {'ewmac4': 0.75, 'ewmac6': 0.25}: weights different by instrument
# 2023-02-02 17:52:13 {'type': 'base_system', 'stage': 'combForecast', 'instrument_code': 'BTC-USDT-SWAP'}  Only this set of rules ['ewmac4', 'ewmac6'] is cheap enough to trade for BTC-USDT-SWAP
# 2023-02-02 17:52:13 {'type': 'base_system', 'stage': 'combForecast', 'instrument_code': 'BTC-USDT-SWAP'}  Using fixed FDM multiplier of 1.000 for BTC-USDT-SWAP
# 2023-02-02 17:52:13 {'type': 'base_system', 'stage': 'combForecast', 'instrument_code': 'BTC-USDT-SWAP'}  No mapping applied for BTC-USDT-SWAP
# 2023-02-02 17:52:13 {'type': 'base_system', 'stage': 'positionSize', 'instrument_code': 'BTC-USDT-SWAP'}  Calculating buffers for BTC-USDT-SWAP
# 2023-02-02 17:52:13 {'type': 'base_system', 'stage': 'positionSize', 'instrument_code': 'BTC-USDT-SWAP'}  Calculating forecast method buffers for BTC-USDT-SWAP
# 2023-02-02 17:52:13 {'type': 'base_system', 'stage': 'accounts'}  Calculating buffered subsystem positions
# 2023-02-02 17:52:13 {'type': 'base_system', 'stage': 'positionSize'}  Getting vol target
# 2023-02-02 17:52:13 {'type': 'base_system', 'stage': 'accounts', 'instrument_code': 'BTC-USDT-SWAP'}  Calculating pandl for subsystem for instrument BTC-USDT-SWAP
# <AxesSubplot:>

# %%
s1 = system.rawdata.normalised_price_for_asset_class("BTC-USDT-SWAP").rename('asset class')
s2 = system.rawdata.get_cumulative_daily_vol_normalised_returns("BTC-USDT-SWAP").rename('BTC')
s3 = system.rawdata.get_cumulative_daily_vol_normalised_returns("ETH-USDT-SWAP").rename('ETH')
s4 = system.rawdata.get_cumulative_daily_vol_normalised_returns("BNB-USDT").rename('BNB')
# ss = [s1, s2, s3, s4]
ss = [select(s, '2023-01-01', '2023-12-31') for s in [s1, s2, s3, s4]]
ss = [s - s.iloc[0] for s in ss]

pd.concat(ss, axis=1).plot(legend=True, figsize=(15,8))
s2
# system.rawdata.get_cumulative_daily_vol_normalised_returns("ADA-USDT-SWAP").rename('ADA').plot(legend=True)
# system.rawdata.get_cumulative_daily_vol_normalised_returns("XRP-USDT-SWAP").rename('XRP').plot(legend=True)
# Out:
# 2023-02-02 17:43:02 {'type': 'base_system', 'stage': 'rawdata', 'instrument_code': 'BNB-USDT'}  Calculating normalised return for BNB-USDT
# 2023-02-02 17:43:02 {'type': 'base_system', 'stage': 'rawdata', 'instrument_code': 'BNB-USDT'}  Calculating daily volatility for BNB-USDT
# 2023-02-02 17:43:02 {'type': 'base_system', 'stage': 'rawdata', 'instrument_code': 'BNB-USDT'}  Calculating daily prices for BNB-USDT
# 2023-02-02 17:43:03 {'type': 'base_system', 'stage': 'rawdata', 'instrument_code': 'BTC-USDT-SWAP'}  Calculating normalised return for BTC-USDT-SWAP
# 2023-02-02 17:43:03 {'type': 'base_system', 'stage': 'rawdata', 'instrument_code': 'ETH-USDT-SWAP'}  Calculating normalised return for ETH-USDT-SWAP
# 2023-02-02 17:43:03 {'type': 'base_system', 'stage': 'rawdata', 'instrument_code': 'ETH-USDT-SWAP'}  Calculating daily volatility for ETH-USDT-SWAP
# 2023-02-02 17:43:03 {'type': 'base_system', 'stage': 'rawdata', 'instrument_code': 'ETH-USDT-SWAP'}  Calculating daily prices for ETH-USDT-SWAP
# /Users/weiranzhou/Code/pysystemtrade/sysobjects/futures_per_contract_prices.py:33: UserWarning: Pandas doesn't allow columns to be created via a new attribute name - see https://pandas.pydata.org/pandas-docs/stable/indexing.html#attribute-access
#   self._as_df = price_data_as_df
# 2023-02-02 17:43:03 {'type': 'base_system', 'stage': 'rawdata', 'instrument_code': 'BTC-USDT-SWAP'}  Calculating cumulative normalised return for BTC-USDT-SWAP
# 2023-02-02 17:43:03 {'type': 'base_system', 'stage': 'rawdata', 'instrument_code': 'ETH-USDT-SWAP'}  Calculating cumulative normalised return for ETH-USDT-SWAP
# 2023-02-02 17:43:03 {'type': 'base_system', 'stage': 'rawdata', 'instrument_code': 'BNB-USDT'}  Calculating cumulative normalised return for BNB-USDT
# index
# 2020-01-01          NaN
# 2020-01-02          NaN
# 2020-01-03          NaN
# 2020-01-04          NaN
# 2020-01-05          NaN
#                 ...
# 2023-01-29    55.136256
# 2023-01-30    55.689307
# 2023-01-31    54.743727
# 2023-02-01    54.854727
# 2023-02-02    56.048096
# Freq: D, Name: BTC, Length: 1129, dtype: float64

# %%
ins_list = ['BTC-USDT-SWAP', 'ETH-USDT-SWAP', 'BNB-USDT']

'''portfolio'''
# print(system.accounts.portfolio().stats())
# system.accounts.portfolio().cumsum().rename('port').plot(legend=True, figsize=(15,8))
# plt.show()


for ins in ins_list:
    curve = system.accounts.pandl_for_subsystem(ins)
    curve.cumsum().rename(ins).plot(legend=True, figsize=(15,8))
    print('{} sharpe={} calmar={}'.format(ins, curve.sharpe(), curve.calmar()))
    plt.show()

    for rule in ['ewmac4', 'relmomentum10']:
        curve = system.accounts.pandl_for_instrument_forecast(ins, rule)
        curve.cumsum().rename('{}-{}'.format(ins, rule)).plot(legend=True, figsize=(15,8))
        print('{}={} sharpe={} calmar={}'.format(ins, rule, curve.sharpe(), curve.calmar()))
    plt.show()
# Out:
# 2023-02-02 17:38:37 {'type': 'base_system', 'stage': 'accounts', 'instrument_code': 'BTC-USDT-SWAP'}  Calculating pandl for subsystem for instrument BTC-USDT-SWAP
# BTC-USDT-SWAP sharpe=1.1874026800196442 calmar=1.7277469228531188
# 2023-02-02 17:38:37 {'type': 'base_system', 'stage': 'accounts', 'instrument_code': 'BTC-USDT-SWAP', 'rule_variation_name': 'ewmac4'}  Calculating pandl for instrument forecast for BTC-USDT-SWAP ewmac4
# BTC-USDT-SWAP=ewmac4 sharpe=1.3302244268513064 calmar=1.5150276276810724
# 2023-02-02 17:38:37 {'type': 'base_system', 'stage': 'accounts', 'instrument_code': 'BTC-USDT-SWAP', 'rule_variation_name': 'relmomentum10'}  Calculating pandl for instrument forecast for BTC-USDT-SWAP relmomentum10
# 2023-02-02 17:38:37 {'type': 'base_system', 'stage': 'forecastScaleCap', 'instrument_code': 'BTC-USDT-SWAP', 'rule_variation_name': 'relmomentum10'}  Calculating capped forecast for BTC-USDT-SWAP relmomentum10
# 2023-02-02 17:38:37 {'type': 'base_system', 'stage': 'rules', 'instrument_code': 'BTC-USDT-SWAP', 'rule_variation_name': 'relmomentum10'}  Calculating raw forecast BTC-USDT-SWAP for relmomentum10
# /Users/weiranzhou/Code/pysystemtrade/sysobjects/futures_per_contract_prices.py:33: UserWarning: Pandas doesn't allow columns to be created via a new attribute name - see https://pandas.pydata.org/pandas-docs/stable/indexing.html#attribute-access
#   self._as_df = price_data_as_df
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[6], line 16
#      13 plt.show()
#      15 for rule in ['ewmac4', 'relmomentum10']:
# ---> 16     curve = system.accounts.pandl_for_instrument_forecast(ins, rule)
#      17     curve.cumsum().rename('{}-{}'.format(ins, rule)).plot(legend=True, figsize=(15,8))
#      18     print('{}={} sharpe={} calmar={}'.format(ins, rule, curve.sharpe(), curve.calmar()))
#
# File ~/Code/pysystemtrade/systems/system_cache.py:723, in stage_access_cache_decorator.<locals>.decorate.<locals>.wrapper(self, *args, **kwargs)
#     720 system = self.parent
#     721 this_stage = self
# --> 723 ans = system.cache.calc_or_cache(
#     724     func,
#     725     this_stage,
#     726     *args,
#     727     protected=protected,
#     728     not_pickable=not_pickable,
#     729     instrument_classify=True,
#     730     **kwargs
#     731 )
#     733 return ans
#
# File ~/Code/pysystemtrade/systems/system_cache.py:573, in systemCache.calc_or_cache(self, func, this_stage, protected, not_pickable, instrument_classify, use_arg_names, *args, **kwargs)
#     568 value = self._get_item_from_cache(cache_ref)
#     570 if value is MISSING_FROM_CACHE:
#     571     # call the function. Note in the original function 'this_stage' was
#     572     # 'self'
# --> 573     value = func(this_stage, *args, **kwargs)
#     574     self.set_item_in_cache(
#     575         value, cache_ref, protected=protected, not_pickable=not_pickable
#     576     )
#     578 return value
#
# File ~/Code/pysystemtrade/paper/systems/accounts/accounts_stage.py:144, in perpetualsAccount.pandl_for_instrument_forecast(self, instrument_code, rule_variation_name, delayfill)
#     113 """
#     114 Get the p&l for one instrument and forecast; as % of arbitrary capital
#     115
#    (...)
#     134
#     135 """
#     137 self.log.msg(
#     138     "Calculating pandl for instrument forecast for %s %s"
#     139     % (instrument_code, rule_variation_name),
#     140     instrument_code=instrument_code,
#     141     rule_variation_name=rule_variation_name,
#     142 )
# --> 144 forecast = self.get_capped_forecast(instrument_code, rule_variation_name)
#     146 price = self.get_raw_price(instrument_code)
#     148 daily_returns_volatility = self.get_daily_returns_volatility(instrument_code)
#
# File ~/Code/pysystemtrade/systems/accounts/account_inputs.py:21, in accountInputs.get_capped_forecast(self, instrument_code, rule_variation_name)
#      18 def get_capped_forecast(
#      19     self, instrument_code: str, rule_variation_name: str
#      20 ) -> pd.Series:
# ---> 21     return self.parent.forecastScaleCap.get_capped_forecast(
#      22         instrument_code, rule_variation_name
#      23     )
#
# File ~/Code/pysystemtrade/systems/system_cache.py:723, in stage_access_cache_decorator.<locals>.decorate.<locals>.wrapper(self, *args, **kwargs)
#     720 system = self.parent
#     721 this_stage = self
# --> 723 ans = system.cache.calc_or_cache(
#     724     func,
#     725     this_stage,
#     726     *args,
#     727     protected=protected,
#     728     not_pickable=not_pickable,
#     729     instrument_classify=True,
#     730     **kwargs
#     731 )
#     733 return ans
#
# File ~/Code/pysystemtrade/systems/system_cache.py:573, in systemCache.calc_or_cache(self, func, this_stage, protected, not_pickable, instrument_classify, use_arg_names, *args, **kwargs)
#     568 value = self._get_item_from_cache(cache_ref)
#     570 if value is MISSING_FROM_CACHE:
#     571     # call the function. Note in the original function 'this_stage' was
#     572     # 'self'
# --> 573     value = func(this_stage, *args, **kwargs)
#     574     self.set_item_in_cache(
#     575         value, cache_ref, protected=protected, not_pickable=not_pickable
#     576     )
#     578 return value
#
# File ~/Code/pysystemtrade/systems/forecast_scale_cap.py:66, in ForecastScaleCap.get_capped_forecast(self, instrument_code, rule_variation_name)
#      33 """
#      34
#      35 Return the capped, scaled,  forecast
#    (...)
#      56 2015-12-11  0.200000
#      57 """
#      59 self.log.msg(
#      60     "Calculating capped forecast for %s %s"
#      61     % (instrument_code, rule_variation_name),
#      62     instrument_code=instrument_code,
#      63     rule_variation_name=rule_variation_name,
#      64 )
# ---> 66 scaled_forecast = self.get_scaled_forecast(instrument_code, rule_variation_name)
#      67 upper_cap = self.get_forecast_cap()
#      68 lower_floor = self.get_forecast_floor()
#
# File ~/Code/pysystemtrade/systems/system_cache.py:723, in stage_access_cache_decorator.<locals>.decorate.<locals>.wrapper(self, *args, **kwargs)
#     720 system = self.parent
#     721 this_stage = self
# --> 723 ans = system.cache.calc_or_cache(
#     724     func,
#     725     this_stage,
#     726     *args,
#     727     protected=protected,
#     728     not_pickable=not_pickable,
#     729     instrument_classify=True,
#     730     **kwargs
#     731 )
#     733 return ans
#
# File ~/Code/pysystemtrade/systems/system_cache.py:573, in systemCache.calc_or_cache(self, func, this_stage, protected, not_pickable, instrument_classify, use_arg_names, *args, **kwargs)
#     568 value = self._get_item_from_cache(cache_ref)
#     570 if value is MISSING_FROM_CACHE:
#     571     # call the function. Note in the original function 'this_stage' was
#     572     # 'self'
# --> 573     value = func(this_stage, *args, **kwargs)
#     574     self.set_item_in_cache(
#     575         value, cache_ref, protected=protected, not_pickable=not_pickable
#     576     )
#     578 return value
#
# File ~/Code/pysystemtrade/systems/forecast_scale_cap.py:99, in ForecastScaleCap.get_scaled_forecast(self, instrument_code, rule_variation_name)
#      76 @diagnostic()
#      77 def get_scaled_forecast(self, instrument_code, rule_variation_name):
#      78     """
#      79     Return the scaled forecast
#      80
#    (...)
#      96     2015-12-11  0.871231
#      97     """
# ---> 99     raw_forecast = self.get_raw_forecast(instrument_code, rule_variation_name)
#     100     forecast_scalar = self.get_forecast_scalar(
#     101         instrument_code, rule_variation_name
#     102     )  # will either be a scalar or a timeseries
#     104     scaled_forecast = raw_forecast * forecast_scalar
#
# File ~/Code/pysystemtrade/systems/system_cache.py:700, in null_decorator.<locals>.wrapper(*args, **kwargs)
#     699 def wrapper(*args, **kwargs):
# --> 700     return func(*args, **kwargs)
#
# File ~/Code/pysystemtrade/systems/forecast_scale_cap.py:133, in ForecastScaleCap.get_raw_forecast(self, instrument_code, rule_variation_name)
#     108 @input
#     109 def get_raw_forecast(
#     110     self, instrument_code: str, rule_variation_name: str
#     111 ) -> pd.Series:
#     112     """
#     113     Convenience method as we use the raw forecast several times
#     114
#    (...)
#     130     2015-12-11  0.164383
#     131     """
# --> 133     raw_forecast = self.rules_stage.get_raw_forecast(
#     134         instrument_code, rule_variation_name
#     135     )
#     137     return raw_forecast
#
# File ~/Code/pysystemtrade/systems/system_cache.py:723, in stage_access_cache_decorator.<locals>.decorate.<locals>.wrapper(self, *args, **kwargs)
#     720 system = self.parent
#     721 this_stage = self
# --> 723 ans = system.cache.calc_or_cache(
#     724     func,
#     725     this_stage,
#     726     *args,
#     727     protected=protected,
#     728     not_pickable=not_pickable,
#     729     instrument_classify=True,
#     730     **kwargs
#     731 )
#     733 return ans
#
# File ~/Code/pysystemtrade/systems/system_cache.py:573, in systemCache.calc_or_cache(self, func, this_stage, protected, not_pickable, instrument_classify, use_arg_names, *args, **kwargs)
#     568 value = self._get_item_from_cache(cache_ref)
#     570 if value is MISSING_FROM_CACHE:
#     571     # call the function. Note in the original function 'this_stage' was
#     572     # 'self'
# --> 573     value = func(this_stage, *args, **kwargs)
#     574     self.set_item_in_cache(
#     575         value, cache_ref, protected=protected, not_pickable=not_pickable
#     576     )
#     578 return value
#
# File ~/Code/pysystemtrade/systems/forecasting.py:100, in Rules.get_raw_forecast(self, instrument_code, rule_variation_name)
#      98 # this will process all the rules, if not already done
#      99 trading_rule_dict = self.trading_rules()
# --> 100 trading_rule = trading_rule_dict[rule_variation_name]
#     102 result = trading_rule.call(system, instrument_code)
#     103 result = pd.Series(result)
#
# KeyError: 'relmomentum10'
