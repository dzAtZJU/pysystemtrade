# %%
from sympy import lambdify, symbols, Piecewise, sqrt
from paper.topic.common_import import *

n = symbols('n')
func = lambdify(n, Piecewise((1 / sqrt(n), True)))
ns = np.arange(350, 401)
_ = plt.figure(figsize=(16, 5))
_ = plt.scatter(ns, func(ns), s=1)
plt.title('sample error')
# Out:
# Text(0.5, 1.0, 'sample error')

# %%
data = pd.Series([10, 100, 1000]).sample(1000, replace=True).reset_index(drop=True)
print(data.mean())
print(data.median())
data.hist(bins=100)
# Out:
# 367.21
# 100.0
# <AxesSubplot:>
