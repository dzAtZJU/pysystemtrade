# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from syscore.fileutils import get_filename_for_package
from paper.systems.crypto_system import perpetuals_system
from itables import show
def select(se, start, end):
    return se[(se.index >= start) &(se.index <= end)]

system = perpetuals_system(config='paper.systems.crypto_v1_base.yaml')
# Out:
# ---------------------------------------------------------------------------
# ParserError                               Traceback (most recent call last)
# Cell In[13], line 10
#       7 def select(se, start, end):
#       8     return se[(se.index >= start) &(se.index <= end)]
# ---> 10 system = perpetuals_system(config='paper.systems.crypto_v1_base.yaml')
#
# File ~/Code/pysystemtrade/paper/systems/crypto_system.py:70, in perpetuals_system(data, config, trading_rules, log_level)
#      68     config = Config('paper.systems.crypto_v0.yaml')
#      69 else:
# ---> 70     config = Config(config)
#      72 rules = Rules(trading_rules)
#      74 system = System(
#      75     [
#      76         perpetualsAccount(),
#    (...)
#      85     config,
#      86 )
#
# File ~/Code/pysystemtrade/sysdata/config/configdata.py:75, in Config.__init__(self, config_object, default_filename, private_filename)
#      72 if config_object is arg_not_supplied:
#      73     config_object = dict()
# ...

# %%
prices = system.data.daily_prices('BTC-USDT-SWAP')

forecast = system.rules.get_raw_forecast('BTC-USDT-SWAP', 'market_effects')
# system.positionSize.get_subsystem_position('BTC-USDT-SWAP').tail(15).plot(secondary_y=True)
# system.portfolio.get_actual_position('BTC-USDT-SWAP').tail(15).plot(secondary_y=True)
# system.accounts.portfolio().tail(15).plot(secondary_y=True)

pandl = system.accounts.pandl_for_instrument_forecast('BTC-USDT-SWAP', 'market_effects')
select(prices, '2022-04-01', '2022-7-16').rename('price').plot(legend=True)
select(forecast, '2022-04-01', '2022-7-16').rename('forecast').plot(legend=True, secondary_y=True)
# select(pandl, '2022-04-01', '2022-7-16').rename('pandl').cumsum().plot(legend=True, secondary_y=True)
# Out:
# /Users/weiranzhou/Code/pysystemtrade/sysobjects/futures_per_contract_prices.py:33: UserWarning: Pandas doesn't allow columns to be created via a new attribute name - see https://pandas.pydata.org/pandas-docs/stable/indexing.html#attribute-access
#   self._as_df = price_data_as_df
# <AxesSubplot:>
