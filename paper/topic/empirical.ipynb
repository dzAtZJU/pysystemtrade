# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from syscore.fileutils import get_filename_for_package
from paper.systems.crypto_system import perpetuals_system

system = perpetuals_system(config='paper.systems.crypto_v1.yaml')
# Out:
# Bad key text.latex.preview in file /opt/homebrew/Caskroom/miniconda/base/envs/trading/lib/python3.8/site-packages/matplotlib/mpl-data/stylelib/_classic_test.mplstyle, line 123 ('text.latex.preview : False')
# You probably need to get an updated matplotlibrc file from
# https://github.com/matplotlib/matplotlib/blob/v3.5.0/matplotlibrc.template
# or from the matplotlib source distribution
#
# Bad key mathtext.fallback_to_cm in file /opt/homebrew/Caskroom/miniconda/base/envs/trading/lib/python3.8/site-packages/matplotlib/mpl-data/stylelib/_classic_test.mplstyle, line 155 ('mathtext.fallback_to_cm : True  # When True, use symbols from the Computer Modern')
# You probably need to get an updated matplotlibrc file from
# https://github.com/matplotlib/matplotlib/blob/v3.5.0/matplotlibrc.template
# or from the matplotlib source distribution
#
# Bad key savefig.jpeg_quality in file /opt/homebrew/Caskroom/miniconda/base/envs/trading/lib/python3.8/site-packages/matplotlib/mpl-data/stylelib/_classic_test.mplstyle, line 418 ('savefig.jpeg_quality: 95       # when a jpeg is saved, the default quality parameter.')
# You probably need to get an updated matplotlibrc file from
# https://github.com/matplotlib/matplotlib/blob/v3.5.0/matplotlibrc.template
# or from the matplotlib source distribution
#
# Bad key savefig.frameon in file /opt/homebrew/Caskroom/miniconda/base/envs/trading/lib/python3.8/site-packages/matplotlib/mpl-data/stylelib/_classic_test.mplstyle, line 421 ('savefig.frameon : True')
# You probably need to get an updated matplotlibrc file from
# https://github.com/matplotlib/matplotlib/blob/v3.5.0/matplotlibrc.template
# or from the matplotlib source distribution
#
# Bad key verbose.level in file /opt/homebrew/Caskroom/miniconda/base/envs/trading/lib/python3.8/site-packages/matplotlib/mpl-data/stylelib/_classic_test.mplstyle, line 472 ('verbose.level  : silent      # one of silent, helpful, debug, debug-annoying')
# You probably need to get an updated matplotlibrc file from
# https://github.com/matplotlib/matplotlib/blob/v3.5.0/matplotlibrc.template
# or from the matplotlib source distribution
#
# Bad key verbose.fileo in file /opt/homebrew/Caskroom/miniconda/base/envs/trading/lib/python3.8/site-packages/matplotlib/mpl-data/stylelib/_classic_test.mplstyle, line 473 ('verbose.fileo  : sys.stdout  # a log filename, sys.stdout or sys.stderr')
# You probably need to get an updated matplotlibrc file from
# https://github.com/matplotlib/matplotlib/blob/v3.5.0/matplotlibrc.template
# or from the matplotlib source distribution
#
# Bad key keymap.all_axes in file /opt/homebrew/Caskroom/miniconda/base/envs/trading/lib/python3.8/site-packages/matplotlib/mpl-data/stylelib/_classic_test.mplstyle, line 490 ('keymap.all_axes : a                 # enable all axes')
# You probably need to get an updated matplotlibrc file from
# https://github.com/matplotlib/matplotlib/blob/v3.5.0/matplotlibrc.template
# or from the matplotlib source distribution
#
# Bad key animation.avconv_path in file /opt/homebrew/Caskroom/miniconda/base/envs/trading/lib/python3.8/site-packages/matplotlib/mpl-data/stylelib/_classic_test.mplstyle, line 501 ('animation.avconv_path: avconv     # Path to avconv binary. Without full path')
# You probably need to get an updated matplotlibrc file from
# https://github.com/matplotlib/matplotlib/blob/v3.5.0/matplotlibrc.template
# or from the matplotlib source distribution
#
# Bad key animation.avconv_args in file /opt/homebrew/Caskroom/miniconda/base/envs/trading/lib/python3.8/site-packages/matplotlib/mpl-data/stylelib/_classic_test.mplstyle, line 503 ('animation.avconv_args:            # Additional arguments to pass to avconv')
# You probably need to get an updated matplotlibrc file from
# https://github.com/matplotlib/matplotlib/blob/v3.5.0/matplotlibrc.template
# or from the matplotlib source distribution
# /opt/homebrew/Caskroom/miniconda/base/envs/trading/lib/python3.8/site-packages/arctic/store/_pandas_ndarray_store.py:8: FutureWarning: The Panel class is removed from pandas. Accessing it from the top-level namespace will also be removed in the next version
#   from pandas import Panel

# %%
system.rawdata.normalised_price_for_asset_class("BTC-USDT-SWAP").rename('asset class').plot(legend=True, figsize=(15,8))
system.rawdata.get_cumulative_daily_vol_normalised_returns("BTC-USDT-SWAP").rename('BTC').plot(legend=True)
system.rawdata.get_cumulative_daily_vol_normalised_returns("ETH-USDT-SWAP").rename('ETH').plot(legend=True)
system.rawdata.get_cumulative_daily_vol_normalised_returns("BNB-USDT").rename('BNB').plot(legend=True)
system.rawdata.get_cumulative_daily_vol_normalised_returns("ADA-USDT-SWAP").rename('ADA').plot(legend=True)
system.rawdata.get_cumulative_daily_vol_normalised_returns("XRP-USDT-SWAP").rename('XRP').plot(legend=True)
# Out:
# 2023-02-01 17:10:38 {'type': 'base_system'}  Following instruments are 'duplicate_markets' ['Another_thing', 'bad_thing']
# 2023-02-01 17:10:38 {'type': 'base_system'}  Following instruments are marked as 'ignore_instruments': not included: ['EXAMPLE']
# 2023-02-01 17:10:38 {'type': 'base_system'}  Following instruments removed entirely from sim: ['Another_thing', 'EXAMPLE', 'bad_thing']
# 2023-02-01 17:10:38 {'type': 'base_system', 'stage': 'rawdata', 'instrument_code': 'BNB-USDT'}  Calculating normalised return for BNB-USDT
# 2023-02-01 17:10:38 {'type': 'base_system', 'stage': 'rawdata', 'instrument_code': 'BNB-USDT'}  Calculating daily volatility for BNB-USDT
# 2023-02-01 17:10:38 {'type': 'base_system', 'stage': 'rawdata', 'instrument_code': 'BNB-USDT'}  Calculating daily prices for BNB-USDT
# /Users/weiranzhou/Code/pysystemtrade/sysobjects/futures_per_contract_prices.py:33: UserWarning: Pandas doesn't allow columns to be created via a new attribute name - see https://pandas.pydata.org/pandas-docs/stable/indexing.html#attribute-access
#   self._as_df = price_data_as_df
# 2023-02-01 17:10:38 {'type': 'base_system', 'stage': 'rawdata', 'instrument_code': 'BTC-USDT-SWAP'}  Calculating normalised return for BTC-USDT-SWAP
# 2023-02-01 17:10:38 {'type': 'base_system', 'stage': 'rawdata', 'instrument_code': 'BTC-USDT-SWAP'}  Calculating daily volatility for BTC-USDT-SWAP
# 2023-02-01 17:10:38 {'type': 'base_system', 'stage': 'rawdata', 'instrument_code': 'BTC-USDT-SWAP'}  Calculating daily prices for BTC-USDT-SWAP
# 2023-02-01 17:10:39 {'type': 'base_system', 'stage': 'rawdata', 'instrument_code': 'ETH-USDT-SWAP'}  Calculating normalised return for ETH-USDT-SWAP
# 2023-02-01 17:10:39 {'type': 'base_system', 'stage': 'rawdata', 'instrument_code': 'ETH-USDT-SWAP'}  Calculating daily volatility for ETH-USDT-SWAP
# 2023-02-01 17:10:39 {'type': 'base_system', 'stage': 'rawdata', 'instrument_code': 'ETH-USDT-SWAP'}  Calculating daily prices for ETH-USDT-SWAP
# 2023-02-01 17:10:39 {'type': 'base_system', 'stage': 'rawdata', 'instrument_code': 'BTC-USDT-SWAP'}  Calculating cumulative normalised return for BTC-USDT-SWAP
# 2023-02-01 17:10:39 {'type': 'base_system', 'stage': 'rawdata', 'instrument_code': 'ETH-USDT-SWAP'}  Calculating cumulative normalised return for ETH-USDT-SWAP
# 2023-02-01 17:10:39 {'type': 'base_system', 'stage': 'rawdata', 'instrument_code': 'BNB-USDT'}  Calculating cumulative normalised return for BNB-USDT
# 2023-02-01 17:10:39 {'type': 'base_system', 'stage': 'rawdata', 'instrument_code': 'ADA-USDT-SWAP'}  Calculating cumulative normalised return for ADA-USDT-SWAP
# 2023-02-01 17:10:39 {'type': 'base_system', 'stage': 'rawdata', 'instrument_code': 'ADA-USDT-SWAP'}  Calculating normalised return for ADA-USDT-SWAP
# 2023-02-01 17:10:39 {'type': 'base_system', 'stage': 'rawdata', 'instrument_code': 'ADA-USDT-SWAP'}  Calculating daily volatility for ADA-USDT-SWAP
# 2023-02-01 17:10:39 {'type': 'base_system', 'stage': 'rawdata', 'instrument_code': 'ADA-USDT-SWAP'}  Calculating daily prices for ADA-USDT-SWAP
# /Users/weiranzhou/Code/pysystemtrade/sysobjects/futures_per_contract_prices.py:33: UserWarning: Pandas doesn't allow columns to be created via a new attribute name - see https://pandas.pydata.org/pandas-docs/stable/indexing.html#attribute-access
#   self._as_df = price_data_as_df
# 2023-02-01 17:10:39 {'type': 'base_system', 'stage': 'rawdata', 'instrument_code': 'XRP-USDT-SWAP'}  Calculating cumulative normalised return for XRP-USDT-SWAP
# 2023-02-01 17:10:39 {'type': 'base_system', 'stage': 'rawdata', 'instrument_code': 'XRP-USDT-SWAP'}  Calculating normalised return for XRP-USDT-SWAP
# 2023-02-01 17:10:39 {'type': 'base_system', 'stage': 'rawdata', 'instrument_code': 'XRP-USDT-SWAP'}  Calculating daily volatility for XRP-USDT-SWAP
# 2023-02-01 17:10:39 {'type': 'base_system', 'stage': 'rawdata', 'instrument_code': 'XRP-USDT-SWAP'}  Calculating daily prices for XRP-USDT-SWAP
# /Users/weiranzhou/Code/pysystemtrade/sysobjects/futures_per_contract_prices.py:33: UserWarning: Pandas doesn't allow columns to be created via a new attribute name - see https://pandas.pydata.org/pandas-docs/stable/indexing.html#attribute-access
#   self._as_df = price_data_as_df
# <AxesSubplot:xlabel='index'>

# %%
ins_list = ['BTC-USDT-SWAP', 'ETH-USDT-SWAP', 'BNB-USDT']

'''portfolio'''
# print(system.accounts.portfolio().stats())
# system.accounts.portfolio().cumsum().rename('port').plot(legend=True, figsize=(15,8))
# plt.show()


for ins in ins_list:
    curve = system.accounts.pandl_for_subsystem(ins)
    curve.cumsum().rename(ins).plot(legend=True, figsize=(15,8))
    print('{} sharpe={} calmar={}'.format(ins, curve.sharpe(), curve.calmar()))
    plt.show()

    for rule in ['ewmac4', 'relmomentum10']:
        curve = system.accounts.pandl_for_instrument_forecast(ins, rule)
        curve.cumsum().rename('{}-{}'.format(ins, rule)).plot(legend=True, figsize=(15,8))
        print('{}={} sharpe={} calmar={}'.format(ins, rule, curve.sharpe(), curve.calmar()))
    plt.show()
# Out:
# 2023-02-01 17:10:40 {'type': 'base_system', 'stage': 'accounts', 'instrument_code': 'BTC-USDT-SWAP'}  Calculating pandl for subsystem for instrument BTC-USDT-SWAP
# /Users/weiranzhou/Code/pysystemtrade/sysobjects/futures_per_contract_prices.py:33: UserWarning: Pandas doesn't allow columns to be created via a new attribute name - see https://pandas.pydata.org/pandas-docs/stable/indexing.html#attribute-access
#   self._as_df = price_data_as_df
# 2023-02-01 17:10:41 {'type': 'base_system', 'stage': 'positionSize', 'instrument_code': 'BTC-USDT-SWAP'}  Calculating subsystem position for BTC-USDT-SWAP
# 2023-02-01 17:10:41 {'type': 'base_system', 'stage': 'positionSize', 'instrument_code': 'BTC-USDT-SWAP'}  Calculating volatility scalar for BTC-USDT-SWAP
# 2023-02-01 17:10:41 {'type': 'base_system', 'stage': 'positionSize', 'instrument_code': 'BTC-USDT-SWAP'}  Calculating instrument value vol for BTC-USDT-SWAP
# 2023-02-01 17:10:41 {'type': 'base_system', 'stage': 'positionSize', 'instrument_code': 'BTC-USDT-SWAP'}  Calculating instrument currency vol for BTC-USDT-SWAP
# 2023-02-01 17:10:41 {'type': 'base_system', 'stage': 'rawdata', 'instrument_code': 'BTC-USDT-SWAP'}  Retrieving natural prices for BTC-USDT-SWAP
# 2023-02-01 17:10:41 {'type': 'base_system', 'stage': 'rawdata', 'instrument_code': 'BTC-USDT-SWAP'}  Calculating daily prices for BTC-USDT-SWAP
# 2023-02-01 17:10:41 {'type': 'base_system', 'stage': 'combForecast', 'instrument_code': 'BTC-USDT-SWAP'}  Calculating combined forecast for BTC-USDT-SWAP
# 2023-02-01 17:10:41 {'type': 'base_system', 'stage': 'forecastScaleCap', 'instrument_code': 'BTC-USDT-SWAP', 'rule_variation_name': 'ewmac4'}  Calculating capped forecast for BTC-USDT-SWAP ewmac4
# 2023-02-01 17:10:41 {'type': 'base_system', 'stage': 'rules', 'instrument_code': 'BTC-USDT-SWAP', 'rule_variation_name': 'ewmac4'}  Calculating raw forecast BTC-USDT-SWAP for ewmac4
# 2023-02-01 17:10:41 {'type': 'base_system', 'stage': 'rawdata', 'instrument_code': 'BTC-USDT-SWAP'}  Calculating daily prices for BTC-USDT-SWAP
# 2023-02-01 17:10:41 {'type': 'base_system', 'stage': 'forecastScaleCap', 'rule_variation_name': 'ewmac4'}  Getting cross sectional forecasts for scalar calculation for ewmac4 over BNB-USDT, BTC-USDT-SWAP, ETH-USDT-SWAP
# 2023-02-01 17:10:41 {'type': 'base_system', 'stage': 'rules', 'instrument_code': 'BNB-USDT', 'rule_variation_name': 'ewmac4'}  Calculating raw forecast BNB-USDT for ewmac4
# 2023-02-01 17:10:41 {'type': 'base_system', 'stage': 'rawdata', 'instrument_code': 'BNB-USDT'}  Calculating daily prices for BNB-USDT
# 2023-02-01 17:10:41 {'type': 'base_system', 'stage': 'rules', 'instrument_code': 'ETH-USDT-SWAP', 'rule_variation_name': 'ewmac4'}  Calculating raw forecast ETH-USDT-SWAP for ewmac4
# 2023-02-01 17:10:41 {'type': 'base_system', 'stage': 'rawdata', 'instrument_code': 'ETH-USDT-SWAP'}  Calculating daily prices for ETH-USDT-SWAP
# 2023-02-01 17:10:42 {'type': 'base_system', 'stage': 'forecastScaleCap', 'instrument_code': 'BTC-USDT-SWAP', 'rule_variation_name': 'relmomentum10'}  Calculating capped forecast for BTC-USDT-SWAP relmomentum10
# 2023-02-01 17:10:42 {'type': 'base_system', 'stage': 'rules', 'instrument_code': 'BTC-USDT-SWAP', 'rule_variation_name': 'relmomentum10'}  Calculating raw forecast BTC-USDT-SWAP for relmomentum10
# 2023-02-01 17:10:42 {'type': 'base_system', 'stage': 'forecastScaleCap', 'rule_variation_name': 'relmomentum10'}  Getting cross sectional forecasts for scalar calculation for relmomentum10 over BNB-USDT, BTC-USDT-SWAP, ETH-USDT-SWAP
# 2023-02-01 17:10:42 {'type': 'base_system', 'stage': 'rules', 'instrument_code': 'BNB-USDT', 'rule_variation_name': 'relmomentum10'}  Calculating raw forecast BNB-USDT for relmomentum10
# 2023-02-01 17:10:42 {'type': 'base_system', 'stage': 'rules', 'instrument_code': 'ETH-USDT-SWAP', 'rule_variation_name': 'relmomentum10'}  Calculating raw forecast ETH-USDT-SWAP for relmomentum10
# 2023-02-01 17:10:42 {'type': 'base_system', 'stage': 'combForecast', 'instrument_code': 'BTC-USDT-SWAP'}  Calculating forecast weights for BTC-USDT-SWAP
# 2023-02-01 17:10:42 {'type': 'base_system', 'stage': 'combForecast'}  Nested dict of forecast weights for BTC-USDT-SWAP {'ewmac4': 0.94, 'relmomentum10': 0.06}: weights different by instrument
# 2023-02-01 17:10:42 {'type': 'base_system', 'stage': 'combForecast', 'instrument_code': 'BTC-USDT-SWAP'}  Only this set of rules ['ewmac4', 'relmomentum10'] is cheap enough to trade for BTC-USDT-SWAP
# 2023-02-01 17:10:42 {'type': 'base_system', 'stage': 'combForecast', 'instrument_code': 'BTC-USDT-SWAP'}  Using fixed FDM multiplier of 1.000 for BTC-USDT-SWAP
# 2023-02-01 17:10:42 {'type': 'base_system', 'stage': 'combForecast', 'instrument_code': 'BTC-USDT-SWAP'}  No mapping applied for BTC-USDT-SWAP
# 2023-02-01 17:10:42 {'type': 'base_system', 'stage': 'positionSize', 'instrument_code': 'BTC-USDT-SWAP'}  Calculating buffers for BTC-USDT-SWAP
# 2023-02-01 17:10:42 {'type': 'base_system', 'stage': 'positionSize', 'instrument_code': 'BTC-USDT-SWAP'}  Calculating forecast method buffers for BTC-USDT-SWAP
# 2023-02-01 17:10:42 {'type': 'base_system', 'stage': 'accounts'}  Calculating buffered subsystem positions
# 2023-02-01 17:10:42 {'type': 'base_system', 'stage': 'positionSize'}  Getting vol target
# BTC-USDT-SWAP sharpe=1.5861821462750434 calmar=2.3134362602060374
# 2023-02-01 17:10:42 {'type': 'base_system', 'stage': 'accounts', 'instrument_code': 'BTC-USDT-SWAP', 'rule_variation_name': 'ewmac4'}  Calculating pandl for instrument forecast for BTC-USDT-SWAP ewmac4
# BTC-USDT-SWAP=ewmac4 sharpe=1.741376975777172 calmar=2.4454732308703084
# 2023-02-01 17:10:42 {'type': 'base_system', 'stage': 'accounts', 'instrument_code': 'BTC-USDT-SWAP', 'rule_variation_name': 'relmomentum10'}  Calculating pandl for instrument forecast for BTC-USDT-SWAP relmomentum10
# BTC-USDT-SWAP=relmomentum10 sharpe=1.3573799846872152 calmar=1.2650439200597394
# /Users/weiranzhou/Code/pysystemtrade/sysobjects/futures_per_contract_prices.py:33: UserWarning: Pandas doesn't allow columns to be created via a new attribute name - see https://pandas.pydata.org/pandas-docs/stable/indexing.html#attribute-access
#   self._as_df = price_data_as_df
# /Users/weiranzhou/Code/pysystemtrade/sysobjects/futures_per_contract_prices.py:33: UserWarning: Pandas doesn't allow columns to be created via a new attribute name - see https://pandas.pydata.org/pandas-docs/stable/indexing.html#attribute-access
#   self._as_df = price_data_as_df
# 2023-02-01 17:10:42 {'type': 'base_system', 'stage': 'accounts', 'instrument_code': 'ETH-USDT-SWAP'}  Calculating pandl for subsystem for instrument ETH-USDT-SWAP
# /Users/weiranzhou/Code/pysystemtrade/sysobjects/futures_per_contract_prices.py:33: UserWarning: Pandas doesn't allow columns to be created via a new attribute name - see https://pandas.pydata.org/pandas-docs/stable/indexing.html#attribute-access
#   self._as_df = price_data_as_df
# 2023-02-01 17:10:43 {'type': 'base_system', 'stage': 'positionSize', 'instrument_code': 'ETH-USDT-SWAP'}  Calculating subsystem position for ETH-USDT-SWAP
# 2023-02-01 17:10:43 {'type': 'base_system', 'stage': 'positionSize', 'instrument_code': 'ETH-USDT-SWAP'}  Calculating volatility scalar for ETH-USDT-SWAP
# 2023-02-01 17:10:43 {'type': 'base_system', 'stage': 'positionSize', 'instrument_code': 'ETH-USDT-SWAP'}  Calculating instrument value vol for ETH-USDT-SWAP
# 2023-02-01 17:10:43 {'type': 'base_system', 'stage': 'positionSize', 'instrument_code': 'ETH-USDT-SWAP'}  Calculating instrument currency vol for ETH-USDT-SWAP
# 2023-02-01 17:10:43 {'type': 'base_system', 'stage': 'rawdata', 'instrument_code': 'ETH-USDT-SWAP'}  Retrieving natural prices for ETH-USDT-SWAP
# 2023-02-01 17:10:43 {'type': 'base_system', 'stage': 'rawdata', 'instrument_code': 'ETH-USDT-SWAP'}  Calculating daily prices for ETH-USDT-SWAP
# 2023-02-01 17:10:43 {'type': 'base_system', 'stage': 'combForecast', 'instrument_code': 'ETH-USDT-SWAP'}  Calculating combined forecast for ETH-USDT-SWAP
# 2023-02-01 17:10:43 {'type': 'base_system', 'stage': 'forecastScaleCap', 'instrument_code': 'ETH-USDT-SWAP', 'rule_variation_name': 'ewmac4'}  Calculating capped forecast for ETH-USDT-SWAP ewmac4
# 2023-02-01 17:10:43 {'type': 'base_system', 'stage': 'forecastScaleCap', 'instrument_code': 'ETH-USDT-SWAP', 'rule_variation_name': 'relmomentum10'}  Calculating capped forecast for ETH-USDT-SWAP relmomentum10
# 2023-02-01 17:10:43 {'type': 'base_system', 'stage': 'combForecast', 'instrument_code': 'ETH-USDT-SWAP'}  Calculating forecast weights for ETH-USDT-SWAP
# 2023-02-01 17:10:43 {'type': 'base_system', 'stage': 'combForecast'}  Nested dict of forecast weights for ETH-USDT-SWAP {'ewmac4': 0.94, 'relmomentum10': 0.06}: weights different by instrument
# 2023-02-01 17:10:43 {'type': 'base_system', 'stage': 'combForecast', 'instrument_code': 'ETH-USDT-SWAP'}  Only this set of rules ['ewmac4', 'relmomentum10'] is cheap enough to trade for ETH-USDT-SWAP
# 2023-02-01 17:10:43 {'type': 'base_system', 'stage': 'combForecast', 'instrument_code': 'ETH-USDT-SWAP'}  Using fixed FDM multiplier of 1.000 for ETH-USDT-SWAP
# 2023-02-01 17:10:43 {'type': 'base_system', 'stage': 'combForecast', 'instrument_code': 'ETH-USDT-SWAP'}  No mapping applied for ETH-USDT-SWAP
# 2023-02-01 17:10:43 {'type': 'base_system', 'stage': 'positionSize', 'instrument_code': 'ETH-USDT-SWAP'}  Calculating buffers for ETH-USDT-SWAP
# 2023-02-01 17:10:43 {'type': 'base_system', 'stage': 'positionSize', 'instrument_code': 'ETH-USDT-SWAP'}  Calculating forecast method buffers for ETH-USDT-SWAP
# 2023-02-01 17:10:43 {'type': 'base_system', 'stage': 'accounts'}  Calculating buffered subsystem positions
# ETH-USDT-SWAP sharpe=1.309267534686778 calmar=1.730726347789512
# 2023-02-01 17:10:43 {'type': 'base_system', 'stage': 'accounts', 'instrument_code': 'ETH-USDT-SWAP', 'rule_variation_name': 'ewmac4'}  Calculating pandl for instrument forecast for ETH-USDT-SWAP ewmac4
# ETH-USDT-SWAP=ewmac4 sharpe=1.5051792131695818 calmar=2.210368596541833
# 2023-02-01 17:10:43 {'type': 'base_system', 'stage': 'accounts', 'instrument_code': 'ETH-USDT-SWAP', 'rule_variation_name': 'relmomentum10'}  Calculating pandl for instrument forecast for ETH-USDT-SWAP relmomentum10
# ETH-USDT-SWAP=relmomentum10 sharpe=1.0767758135920762 calmar=1.0641968941610194
# /Users/weiranzhou/Code/pysystemtrade/sysobjects/futures_per_contract_prices.py:33: UserWarning: Pandas doesn't allow columns to be created via a new attribute name - see https://pandas.pydata.org/pandas-docs/stable/indexing.html#attribute-access
#   self._as_df = price_data_as_df
# /Users/weiranzhou/Code/pysystemtrade/sysobjects/futures_per_contract_prices.py:33: UserWarning: Pandas doesn't allow columns to be created via a new attribute name - see https://pandas.pydata.org/pandas-docs/stable/indexing.html#attribute-access
#   self._as_df = price_data_as_df
# 2023-02-01 17:10:43 {'type': 'base_system', 'stage': 'accounts', 'instrument_code': 'BNB-USDT'}  Calculating pandl for subsystem for instrument BNB-USDT
# 2023-02-01 17:10:44 {'type': 'base_system', 'stage': 'positionSize', 'instrument_code': 'BNB-USDT'}  Calculating subsystem position for BNB-USDT
# 2023-02-01 17:10:44 {'type': 'base_system', 'stage': 'positionSize', 'instrument_code': 'BNB-USDT'}  Calculating volatility scalar for BNB-USDT
# 2023-02-01 17:10:44 {'type': 'base_system', 'stage': 'positionSize', 'instrument_code': 'BNB-USDT'}  Calculating instrument value vol for BNB-USDT
# 2023-02-01 17:10:44 {'type': 'base_system', 'stage': 'positionSize', 'instrument_code': 'BNB-USDT'}  Calculating instrument currency vol for BNB-USDT
# 2023-02-01 17:10:44 {'type': 'base_system', 'stage': 'rawdata', 'instrument_code': 'BNB-USDT'}  Retrieving natural prices for BNB-USDT
# /Users/weiranzhou/Code/pysystemtrade/sysobjects/futures_per_contract_prices.py:33: UserWarning: Pandas doesn't allow columns to be created via a new attribute name - see https://pandas.pydata.org/pandas-docs/stable/indexing.html#attribute-access
#   self._as_df = price_data_as_df
# 2023-02-01 17:10:44 {'type': 'base_system', 'stage': 'rawdata', 'instrument_code': 'BNB-USDT'}  Calculating daily prices for BNB-USDT
# 2023-02-01 17:10:44 {'type': 'base_system', 'stage': 'combForecast', 'instrument_code': 'BNB-USDT'}  Calculating combined forecast for BNB-USDT
# 2023-02-01 17:10:44 {'type': 'base_system', 'stage': 'forecastScaleCap', 'instrument_code': 'BNB-USDT', 'rule_variation_name': 'ewmac4'}  Calculating capped forecast for BNB-USDT ewmac4
# 2023-02-01 17:10:44 {'type': 'base_system', 'stage': 'forecastScaleCap', 'instrument_code': 'BNB-USDT', 'rule_variation_name': 'relmomentum10'}  Calculating capped forecast for BNB-USDT relmomentum10
# 2023-02-01 17:10:44 {'type': 'base_system', 'stage': 'combForecast', 'instrument_code': 'BNB-USDT'}  Calculating forecast weights for BNB-USDT
# 2023-02-01 17:10:44 {'type': 'base_system', 'stage': 'combForecast'}  Nested dict of forecast weights for BNB-USDT {'ewmac4': 1, 'relmomentum10': 0}: weights different by instrument
# 2023-02-01 17:10:44 {'type': 'base_system', 'stage': 'combForecast', 'instrument_code': 'BNB-USDT'}  Only this set of rules ['ewmac4', 'relmomentum10'] is cheap enough to trade for BNB-USDT
# 2023-02-01 17:10:44 {'type': 'base_system', 'stage': 'combForecast', 'instrument_code': 'BNB-USDT'}  Using fixed FDM multiplier of 1.000 for BNB-USDT
# 2023-02-01 17:10:44 {'type': 'base_system', 'stage': 'combForecast', 'instrument_code': 'BNB-USDT'}  No mapping applied for BNB-USDT
# 2023-02-01 17:10:44 {'type': 'base_system', 'stage': 'positionSize', 'instrument_code': 'BNB-USDT'}  Calculating buffers for BNB-USDT
# 2023-02-01 17:10:44 {'type': 'base_system', 'stage': 'positionSize', 'instrument_code': 'BNB-USDT'}  Calculating forecast method buffers for BNB-USDT
# 2023-02-01 17:10:44 {'type': 'base_system', 'stage': 'accounts'}  Calculating buffered subsystem positions
# BNB-USDT sharpe=1.1184028078999015 calmar=1.3358938282651835
# 2023-02-01 17:10:44 {'type': 'base_system', 'stage': 'accounts', 'instrument_code': 'BNB-USDT', 'rule_variation_name': 'ewmac4'}  Calculating pandl for instrument forecast for BNB-USDT ewmac4
# BNB-USDT=ewmac4 sharpe=1.4244133701009556 calmar=1.6926296846009228
# 2023-02-01 17:10:44 {'type': 'base_system', 'stage': 'accounts', 'instrument_code': 'BNB-USDT', 'rule_variation_name': 'relmomentum10'}  Calculating pandl for instrument forecast for BNB-USDT relmomentum10
# BNB-USDT=relmomentum10 sharpe=0.6406837905145187 calmar=0.5519009566745929
# /Users/weiranzhou/Code/pysystemtrade/sysobjects/futures_per_contract_prices.py:33: UserWarning: Pandas doesn't allow columns to be created via a new attribute name - see https://pandas.pydata.org/pandas-docs/stable/indexing.html#attribute-access
#   self._as_df = price_data_as_df
# /Users/weiranzhou/Code/pysystemtrade/sysobjects/futures_per_contract_prices.py:33: UserWarning: Pandas doesn't allow columns to be created via a new attribute name - see https://pandas.pydata.org/pandas-docs/stable/indexing.html#attribute-access
#   self._as_df = price_data_as_df
