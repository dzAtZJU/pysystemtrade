# %%
from sysdata.csv.csv_adjusted_prices import csvFuturesAdjustedPricesData
ap = csvFuturesAdjustedPricesData('sysinit.china.adjusted_prices_csv')
hcap = ap.get_adjusted_prices('HC')
hcap.plot()

from sysdata.csv.csv_multiple_prices import csvFuturesMultiplePricesData

mp = csvFuturesMultiplePricesData('sysinit.china.multiple_prices_csv')
hcmp = mp.get_multiple_prices('HC')
hcmp['PRICE'].plot()

(hcmp['FORWARD'] - hcmp['PRICE']).sum()
# Out:
# -2739.0
