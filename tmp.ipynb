# %%
from paper.tmp import ccxt, exchange, tmp, _tmp
from itables import show

# print(ccxt.exchanges)

# exchange = exchange('biance')
# symbol = 'BTC/USDT'
# show(_tmp('2000-11-28T10:00+08', symbol, exchange))

# exchange = exchange('coinbaseprime')
# symbol = 'BTC/USDT'
# show(_tmp('2021-05-28T10:00+08', symbol, exchange))

exchange = exchange('okex5')
symbol = 'ADA-USDT-SWAP'

from syscore.fileutils import get_filename_for_package
tmp('2020-08-01T10:00+08', symbol, exchange).to_csv(get_filename_for_package('paper.data.{}.csv'.format(symbol)))
# Out:
# 1596247200000
# 1596603600000
# 1596960000000
# 1597316400000
# 1597672800000
# 1598029200000
# 1598385600000
# 1598742000000
# 1599098400000
# 1599454800000
# 1599811200000
# 1600167600000
# 1600524000000
# 1600880400000
# 1601236800000
# 1601593200000
# 1601949600000
# 1602306000000
# 1602662400000
# 1603018800000
# 1603375200000
# 1603731600000
# 1604088000000
# 1604444400000
# 1604800800000
# 1605157200000
# 1605513600000
# 1605870000000
# 1606226400000
# 1606582800000
# 1606939200000
# 1607295600000
# 1607652000000
# 1608008400000
# 1608364800000
# 1608721200000
# 1609077600000
# 1609434000000
# 1609790400000
# 1610146800000
# 1610503200000
# 1610859600000
# 1611216000000
# 1611572400000
# 1611928800000
# 1612285200000
# 1612641600000
# 1612998000000
# 1613354400000
# 1613710800000
# 1614067200000
# 1614423600000
# 1614780000000
# 1615136400000
# 1615492800000
# 1615849200000
# 1616205600000
# 1616562000000
# 1616918400000
# 1617274800000
# 1617631200000
# 1617987600000
# ...

# %%
import pandas as pd

pd.to_datetime(1672902000000, unit='ms', utc=True).tz_convert('Asia/Hong_Kong').tz_localize(None)
# Out:
# Timestamp('2023-01-05 15:00:00')
